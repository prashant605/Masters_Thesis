# %% [markdown]
# # **CODE 8b: XGBoost MODEL TRAINING (Nifty 100)**
#
# Trains an XGBoost conviction classifier using walk-forward validation, a financial-utility scoring function, inverse-frequency class weights, and a hybrid RandomOverSampler (search) + SMOTENC (final) resampling strategy.
#
# ---
#
# ## Input files (from Google Drive)
# | File | Source | Purpose |
# |------|--------|---------|
# | `train_data_nifty100.parquet` | Code 8a | Cleaned train split (2011–2019) + `date`, `symbol`, `conviction_label` |
# | `feature_metadata_nifty100.csv` | Code 8a | Feature list (model features only) |
# | `feature_reference.csv` | project | Drives data-quality checks; `xgb_relevant='No'` features ignored |
# | `features_to_prune.csv` *(optional)* | you | One column `feature_name`; features to drop on a re-run |
#
# ## Output files (auto-downloaded to your Downloads folder)
# | File | Purpose |
# |------|---------|
# | `best_model.pkl` | Trained XGBoost model |
# | `label_mapping.pkl` | Conviction→numeric mapping (Code 8c loads this) |
# | `categorical_encoders.pkl` | Label encoders for categorical features |
# | `feature_columns_model.pkl` | Exact feature list & order used (Code 8c loads this) |
# | `feature_importance.csv` | Feature importance ranking |
# | `data_quality_before.csv` | NaN / inf / blank / dtype per column BEFORE cleaning |
# | `data_quality_after.csv` | NaN / inf / blank / dtype per column AFTER cleaning |
# | `cleaning_report.csv` | **Column-wise before/after NaN+inf+blank, cleaning method, fill value** |
# | `training_results.csv` | Per-iteration search summary |
# | `cv_fold_metrics.csv` | Per-fold metrics |
# | `best_hyperparameters.txt` | Winning hyperparameters |
#
# ---
#
# ## Key methodological points
# - **No scaling, no cyclical encoding** — XGBoost handles raw magnitudes; only NaN handling & label-encoding of categoricals is done. This differs from the LSTM pipeline.
# - **`n_estimators` is a tuned hyperparameter** (no early stopping) — the final model uses exactly the tree count that was cross-validated. See note in Step 7.
# - **Walk-forward validation:** Train≤2016→Val 2017, ≤2017→2018, ≤2018→2019.
# - **Conviction label mapping is fixed and printed** — must match Code 8c.
#
# ---

# %% [markdown]
# ## **STEP 0: Mount Google Drive**

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
print("\n" + "="*80)
print("Google Drive mounted successfully!")
print("="*80)
# Out:
# Mounted at /content/drive
#
# ================================================================================
# Google Drive mounted successfully!
# ================================================================================

# %% [markdown]
# ## **STEP 1: Import Libraries**

# %%
import pandas as pd
import numpy as np
import pickle
from datetime import datetime
import time
import warnings
warnings.filterwarnings('ignore')

import xgboost as xgb
from sklearn.model_selection import ParameterSampler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import RandomOverSampler   # fast — used in search
from imblearn.over_sampling import SMOTENC             # quality — used for final model

print("="*80)
print("CODE 8b: XGBoost MODEL TRAINING")
print("="*80)
print(f"\n✓ Libraries imported  |  XGBoost {xgb.__version__}")
print(f"  Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print()
# Out:
# ================================================================================
# CODE 8b: XGBoost MODEL TRAINING
# ================================================================================
#
# ✓ Libraries imported  |  XGBoost 3.3.0
#   Time: 2026-08-18 10:00:12

# %% [markdown]
# ## **STEP 2: Configuration**
#
# **⚠️ Update `DRIVE_FOLDER`.** Review oversampling targets and the label mapping printed below.

# %%
# ── UPDATE THIS PATH ────────────────────────────────────────────────────────
DRIVE_FOLDER = '/content/drive/MyDrive/masters/'

SUFFIX = 'midcap150'   # stock universe (matches Code 8a output suffix)

# Input files (Google Drive)
TRAIN_FILE     = os.path.join(DRIVE_FOLDER, f'train_data_{SUFFIX}.parquet')
METADATA_FILE  = os.path.join(DRIVE_FOLDER, f'feature_metadata_{SUFFIX}.csv')
FEATURE_REF_FILE = os.path.join(DRIVE_FOLDER, 'feature_reference.csv')

# ── Inter-stock feature toggle (for ablation: with vs without inter-stock) ──
# When True, drops every feature where feature_reference inter_stock_dependency == 'Yes'
# (cluster, counter-cluster, commodity, relative-strength-vs-sector, etc.).
# Run once with False and once with True to compare model performance.
DROP_INTER_STOCK = False   # ← set True to exclude inter-stock features

# Optional prune file (set to a path on a re-run; None on first run)
PRUNE_FILE = os.path.join(DRIVE_FOLDER, 'features_to_prune.csv') # e.g. None   # e.g. os.path.join(DRIVE_FOLDER, 'features_to_prune.csv')

# Output folder (Colab local, auto-downloaded at the end)
OUTPUT_FOLDER = '/content/model_outputs/'
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# ── Search configuration ────────────────────────────────────────────────────
# ── Per-combination outputs (Requests 1 & 2) ───────────────────────────────
SAVE_COMBO_MODELS = True   # Req1: save each combo's full-data final model
COLLECT_GAIN      = True   # Req2: per-feature gain for every fold × combo

N_ITER       = 500     # hyperparameter combinations sampled from the grid
RANDOM_STATE = 42

# ── Conviction label mapping (MUST match Code 8c) ───────────────────────────
LABEL_MAPPING_CONFIG = {'Ignore': 0, 'Low': 1, 'Medium': 2, 'High': 3}  # matches Code 7

# ── Oversampling targets per class (None = leave untouched) ─────────────────
# DISABLED: class imbalance is handled by (a) tuned class weights and (b) the
# expected-utility decision rule. Oversampling machinery kept intact but dormant.
OVERSAMPLE_TARGETS = {
    0: None,   # Ignore  — untouched
    1: None,   # Low     — untouched
    2: None,   # Medium  — untouched
    3: None,   # High    — untouched
}

print("-"*80)
print("CONFIGURATION")
print("-"*80)
print(f"  Universe       : {SUFFIX}")
print(f"  Train file     : {TRAIN_FILE}")
print(f"  Search iters   : {N_ITER}")
print(f"  Prune file     : {PRUNE_FILE if PRUNE_FILE else 'None (first run)'}")

print("\nConviction label → numeric mapping (MUST match Code 8c):")
for lbl, num in sorted(LABEL_MAPPING_CONFIG.items(), key=lambda x: x[1]):
    print(f"    {num}  =  {lbl}")

print("\nOversampling targets (None = untouched):")
for cls, tgt in OVERSAMPLE_TARGETS.items():
    lbl = [k for k,v in LABEL_MAPPING_CONFIG.items() if v == cls][0]
    print(f"    Class {cls} ({lbl:8s}): {'untouched' if tgt is None else f'target {tgt:.0%}'}")
print()

for fpath, name in [(TRAIN_FILE,'train parquet'), (METADATA_FILE,'metadata'),
                    (FEATURE_REF_FILE,'feature_reference')]:
    if not os.path.exists(fpath):
        raise FileNotFoundError(f"{name} not found: {fpath}")
    print(f"  ✓ {name}")
print()
# Out:
# --------------------------------------------------------------------------------
# CONFIGURATION
# --------------------------------------------------------------------------------
#   Universe       : midcap150
#   Train file     : /content/drive/MyDrive/masters/train_data_midcap150.parquet
#   Search iters   : 500
#   Prune file     : /content/drive/MyDrive/masters/features_to_prune.csv
#
# Conviction label → numeric mapping (MUST match Code 8c):
#     0  =  Ignore
#     1  =  Low
#     2  =  Medium
#     3  =  High
#
# Oversampling targets (None = untouched):
#     Class 0 (Ignore  ): untouched
#     Class 1 (Low     ): untouched
#     Class 2 (Medium  ): untouched
#     Class 3 (High    ): untouched
#
#   ✓ train parquet
#   ✓ metadata
#   ✓ feature_reference

# %% [markdown]
# ## **STEP 3: Load Data**

# %%
print("-"*80)
print("LOADING DATA")
print("-"*80)

train_df    = pd.read_parquet(TRAIN_FILE)
metadata_df = pd.read_csv(METADATA_FILE)
feature_ref = pd.read_csv(FEATURE_REF_FILE)

print(f"✓ train_data    : {len(train_df):,} rows, {len(train_df.columns)} columns")
print(f"✓ feature_meta  : {len(metadata_df)} features")
print(f"✓ feature_ref   : {len(feature_ref)} catalogued features")

feature_columns_all = metadata_df['feature_name'].tolist()
print(f"\nFeatures from metadata: {len(feature_columns_all)}")
print()
# Out:
# --------------------------------------------------------------------------------
# LOADING DATA
# --------------------------------------------------------------------------------
# ✓ train_data    : 286,739 rows, 278 columns
# ✓ feature_meta  : 275 features
# ✓ feature_ref   : 347 catalogued features
#
# Features from metadata: 275

# %% [markdown]
# ## **STEP 4: Data Quality Report — BEFORE cleaning**
#
# Per-column NaN count, blank/empty count, and dtype, saved to `data_quality_before.csv`.

# %%
print("-"*80)
print("DATA QUALITY REPORT — BEFORE CLEANING  (train split, 2011-2019)")
print("-"*80)

def data_quality_report(df, cols):
    """Per-column NaN, inf, blank, dtype, unique. inf counted for numeric cols."""
    rows = []
    n = len(df)
    for c in cols:
        if c not in df.columns:
            continue
        s = df[c]
        nan_ct = int(s.isnull().sum())
        if s.dtype.kind in 'fiu':
            inf_ct   = int(np.isinf(s.to_numpy(dtype='float64', na_value=np.nan)).sum())
            blank_ct = 0
        else:
            inf_ct   = 0
            blank_ct = int((s.astype(str).str.strip() == '').sum())
        rows.append({
            'feature'     : c,
            'dtype'       : str(s.dtype),
            'n_nan'       : nan_ct,
            'n_inf'       : inf_ct,
            'n_blank'     : blank_ct,
            'pct_missing' : round((nan_ct + inf_ct) / n * 100, 3),
            'n_unique'    : int(s.nunique(dropna=True)),
        })
    return pd.DataFrame(rows).sort_values('pct_missing', ascending=False)

dq_before = data_quality_report(train_df, feature_columns_all)
dq_before.to_csv(os.path.join(OUTPUT_FOLDER, 'data_quality_before.csv'), index=False)

print(f"Columns with NaN  : {(dq_before['n_nan']>0).sum()} / {len(dq_before)}")
print(f"Columns with inf  : {(dq_before['n_inf']>0).sum()} / {len(dq_before)}")
print(f"Total NaN cells   : {dq_before['n_nan'].sum():,}")
print(f"Total inf cells   : {dq_before['n_inf'].sum():,}")
print("\nTop 15 columns by % missing (NaN+inf):")
print(dq_before.head(15).to_string(index=False))
print("\n✓ Saved: data_quality_before.csv")
print()
# Out:
# --------------------------------------------------------------------------------
# DATA QUALITY REPORT — BEFORE CLEANING  (train split, 2011-2019)
# --------------------------------------------------------------------------------
# Columns with NaN  : 52 / 275
# Columns with inf  : 0 / 275
# Total NaN cells   : 12,159,206
# Total inf cells   : 0
#
# Top 15 columns by % missing (NaN+inf):
#                   feature   dtype  n_nan  n_inf  n_blank  pct_missing  n_unique
#          mapped_commodity  object 276421      0        0       96.402         7
#       commodity_direction float32 276421      0        0       96.402         2
#     commodity_correlation float32 276421      0        0       96.402        42
#       commodity_return_2d float32 236226      0        0       82.384      4874
# commodity_volatility_120d float32 236226      0        0       82.384      4895
#  commodity_volatility_60d float32 236226      0        0       82.384      4899
#  commodity_volatility_20d float32 236226      0        0       82.384      4898
#  commodity_volatility_10d float32 236226      0        0       82.384      4897
#   commodity_volatility_5d float32 236226      0        0       82.384      4899
#     commodity_return_252d float32 236226      0        0       82.384      4900
#     commodity_return_120d float32 236226      0        0       82.384      4894
#      commodity_return_60d float32 236226      0        0       82.384      4898
#      commodity_return_20d float32 236226      0        0       82.384      4893
#      commodity_return_10d float32 236226      0        0       82.384      4890
#       commodity_return_5d float32 236226      0        0       82.384      4892
#
# ✓ Saved: data_quality_before.csv

# %% [markdown]
# ## **STEP 5: Feature Selection + Per-Feature NaN Handling**
#
# Drops identifiers and `xgb_relevant='No'` features, applies any prune list, then handles residual NaNs using `feature_reference.csv` guidance (mean/mode/zero/forward-fill). XGBoost-specific: no scaling, no cyclical encoding.

# %%
print("-"*80)
print("FEATURE SELECTION")
print("-"*80)

# Drop identifiers — never model features (carried only for folds/sim)
IDENTIFIERS = {'date','Date','DATE','symbol','Symbol','ticker','Ticker'}
feature_columns = [c for c in feature_columns_all if c not in IDENTIFIERS]
dropped_ids = [c for c in feature_columns_all if c in IDENTIFIERS]
if dropped_ids:
    print(f"  Dropped identifiers: {dropped_ids}")

# Drop xgb_relevant == 'No'
xgb_no = set(feature_ref.loc[feature_ref['xgb_relevant'] == 'No', 'feature_name'])
dropped_xgb = [c for c in feature_columns if c in xgb_no]
feature_columns = [c for c in feature_columns if c not in xgb_no]
print(f"  Dropped xgb_relevant='No': {len(dropped_xgb)} features")

# Inter-stock toggle: drop features with inter_stock_dependency == 'Yes'
if DROP_INTER_STOCK:
    inter_yes = set(feature_ref.loc[
        feature_ref['inter_stock_dependency'].astype(str).str.strip().str.lower() == 'yes',
        'feature_name'])
    dropped_inter = [c for c in feature_columns if c in inter_yes]
    feature_columns = [c for c in feature_columns if c not in inter_yes]
    print(f"  DROP_INTER_STOCK=True → dropped {len(dropped_inter)} inter-stock features")
    print(f"    e.g. {dropped_inter[:8]}{' ...' if len(dropped_inter) > 8 else ''}")
else:
    n_inter = int((feature_ref['inter_stock_dependency'].astype(str)
                   .str.strip().str.lower() == 'yes').sum())
    print(f"  DROP_INTER_STOCK=False → keeping inter-stock features "
          f"({n_inter} such features in reference)")

# Optional prune list
print("\nFeature pruning:")
if PRUNE_FILE and os.path.exists(PRUNE_FILE):
    prune_list = pd.read_csv(PRUNE_FILE)['feature_name'].dropna().tolist()
    found     = [c for c in prune_list if c in feature_columns]
    not_found = [c for c in prune_list if c not in feature_columns]
    feature_columns = [c for c in feature_columns if c not in found]
    print(f"  {'Feature':<40} {'In Dataset?':<12} Action")
    print(f"  {'-'*40} {'-'*12} {'-'*8}")
    for f in found:     print(f"  {f:<40} {'Yes':<12} PRUNED")
    for f in not_found: print(f"  {f:<40} {'NOT FOUND':<12} skipped")
    print(f"\n  Pruned: {len(found)}  |  not found: {len(not_found)}")
elif PRUNE_FILE:
    print(f"  ⚠️  Prune file not found: {PRUNE_FILE} — no pruning")
else:
    print(f"  PRUNE_FILE = None — no pruning (first run)")

print(f"\n  Final feature count: {len(feature_columns)}")
print()

# ── Extract X / y ───────────────────────────────────────────────────────────
X_train = train_df[feature_columns].copy()
y_train = train_df['conviction_label'].copy()
print(f"X_train: {X_train.shape}   y_train: {y_train.shape}")

# ── NaN / inf handling (data already cleaned in Code 8a; this is a safety net) ──
# Strategy column is 'nan_handling' in feature_reference:
#   drop_row     : already applied in 8a — any residual NaN row is dropped here too
#   forward_fill : already filled per-stock in 8a
#   keep_nan     : NaN intentionally retained — XGBoost handles numeric NaN natively;
#                  categorical keep_nan cols get an explicit 'Missing' category
print("\nNaN / inf handling (safety net — main cleaning done in Code 8a)...")
nan_strategy = dict(zip(feature_ref['feature_name'], feature_ref['nan_handling']))

def resolve_strategy(col):
    raw = str(nan_strategy.get(col, 'forward_fill'))
    if 'drop_row' in raw:     return 'drop_row'
    if 'keep_nan' in raw:     return 'keep_nan'
    if 'forward_fill' in raw: return 'forward_fill'
    return 'forward_fill'

col_method = {c: resolve_strategy(c) for c in feature_columns}

# Convert inf/-inf → NaN (XGBoost rejects inf, accepts NaN)
_num = X_train.select_dtypes(include=[np.number]).columns
_n_inf = int(np.isinf(X_train[_num].to_numpy(dtype='float64', na_value=np.nan)).sum())
if _n_inf > 0:
    X_train[_num] = X_train[_num].replace([np.inf, -np.inf], np.nan)
    print(f"  Converted {_n_inf:,} inf/-inf → NaN")

# drop_row safety net: drop rows still NaN in any drop_row feature
drop_cols = [c for c in feature_columns if col_method[c] == 'drop_row']
if drop_cols:
    before = len(X_train)
    keep_mask = X_train[drop_cols].notnull().all(axis=1)
    X_train = X_train[keep_mask]
    y_train = y_train[keep_mask]
    if before - len(X_train) > 0:
        print(f"  drop_row safety net: removed {before-len(X_train):,} rows "
              f"with NaN in {len(drop_cols)} drop_row columns")

# forward_fill safety net: per-stock fill if any residual (no inter-stock data)
ff_cols = [c for c in feature_columns if col_method[c] == 'forward_fill']
ff_resid = [c for c in ff_cols if X_train[c].isnull().any()]
if ff_resid:
    print(f"  forward_fill safety net: {len(ff_resid)} columns had residual NaN")
    # No date/ticker index inside X_train; these are start-of-history gaps.
    # For numeric, fill with column median as a last resort (rare).
    for c in ff_resid:
        if X_train[c].dtype.kind in 'fiu':
            X_train[c] = X_train[c].fillna(X_train[c].median())

# keep_nan: leave numeric NaN as-is; give categoricals an explicit category
keep_cols = [c for c in feature_columns if col_method[c] == 'keep_nan']
print(f"  keep_nan columns: {len(keep_cols)} (numeric NaN retained for XGBoost)")
print(f"  Residual NaN in features (mostly intentional keep_nan): "
      f"{X_train[feature_columns].isnull().sum().sum():,}")
print()
# Out:
# --------------------------------------------------------------------------------
# FEATURE SELECTION
# --------------------------------------------------------------------------------
#   Dropped xgb_relevant='No': 0 features
#   DROP_INTER_STOCK=False → keeping inter-stock features (218 such features in reference)
#
# Feature pruning:
#   Feature                                  In Dataset?  Action
#   ---------------------------------------- ------------ --------
#   commodity_direction                      Yes          PRUNED
#   RS_vs_Cluster_1d                         Yes          PRUNED
#   cluster_return_1d                        Yes          PRUNED
#   Return_5d                                Yes          PRUNED
#   cluster_z_score_20d                      Yes          PRUNED
#   Sortino_20d                              Yes          PRUNED
#   Excess_Ret_N500_1d                       Yes          PRUNED
#   cluster_z_score_120d                     Yes          PRUNED
#   Excess_Ret_N500_20d_Rank                 Yes          PRUNED
#   Return_20d                               Yes          PRUNED
#   Sharpe_20d                               Yes          PRUNED
#   Return_60d                               Yes          PRUNED
#   Days_Since_52W_High                      Yes          PRUNED
#   Lower_Lows_Count_20d                     Yes          PRUNED
#   Quarter                                  Yes          PRUNED
#   Return_1d                                Yes          PRUNED
#   Sharpe_60d                               Yes          PRUNED
#   Sortino_60d                              Yes          PRUNED
#   commodity_distance_from_high_60d         Yes          PRUNED
#
#   Pruned: 19  |  not found: 0
#
#   Final feature count: 256
#
# X_train: (286739, 256)   y_train: (286739,)
#
# NaN / inf handling (safety net — main cleaning done in Code 8a)...
#   forward_fill safety net: 46 columns had residual NaN
#   keep_nan columns: 15 (numeric NaN retained for XGBoost)
#   Residual NaN in features (mostly intentional keep_nan): 780,163

# %% [markdown]
# ## **STEP 6: Data Quality Report — AFTER cleaning + Encode Categoricals + Label Mapping**
#
# Confirms no NaNs remain, label-encodes categorical features (XGB needs numeric), and shows the conviction mapping and class weights.

# %%
print("-"*80)
print("DATA QUALITY REPORT — AFTER CLEANING  (train split, 2011-2019)")
print("-"*80)
dq_after = data_quality_report(X_train, feature_columns)
dq_after.to_csv(os.path.join(OUTPUT_FOLDER, 'data_quality_after.csv'), index=False)

# ── Merge BEFORE + AFTER + cleaning method into one column-wise report ──────
# 'col_method' was recorded during the residual NaN handling step (Step 5)
method_map = col_method      # recorded in Step 5

merged = dq_before.merge(
    dq_after, on='feature', how='right', suffixes=('_before', '_after'))
merged['cleaning_method'] = merged['feature'].map(
    lambda c: method_map.get(c, 'none'))

# Tidy column order
report_cols = ['feature', 'dtype_after', 'cleaning_method',
               'n_nan_before', 'n_inf_before', 'n_blank_before', 'pct_missing_before',
               'n_nan_after', 'n_inf_after', 'n_blank_after', 'pct_missing_after']
report_cols = [c for c in report_cols if c in merged.columns]
cleaning_report = merged[report_cols].sort_values('pct_missing_before', ascending=False)
cleaning_report.to_csv(os.path.join(OUTPUT_FOLDER, 'cleaning_report.csv'), index=False)

print(f"Columns with NaN after : {(dq_after['n_nan']>0).sum()} / {len(dq_after)}")
print(f"Columns with inf after : {(dq_after['n_inf']>0).sum()} / {len(dq_after)}")
print(f"Total NaN after        : {dq_after['n_nan'].sum():,}")
print(f"Total inf after        : {dq_after['n_inf'].sum():,}")

residual = cleaning_report[(cleaning_report.get('n_nan_after', 0) > 0) |
                           (cleaning_report.get('n_inf_after', 0) > 0)]
if len(residual) > 0:
    print(f"\n⚠️  {len(residual)} columns still have NaN/inf after cleaning:")
    print(residual[['feature','cleaning_method','n_nan_after','n_inf_after']].to_string(index=False))
else:
    print("\n✓ No residual NaN/inf in any feature after cleaning")

print("\n✓ Saved: data_quality_after.csv, cleaning_report.csv (column-wise before/after + method)")
print()

# ── Encode categorical features (label encoding — XGB needs numeric) ────────
print("Encoding categorical features (no scaling / no embedding for XGB)...")
categorical_columns = X_train.select_dtypes(include=['object','category']).columns.tolist()
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col].fillna('Unknown').astype(str))
    label_encoders[col] = le
    print(f"  {col:30s} → {len(le.classes_)} categories")
categorical_indices = [feature_columns.index(c) for c in categorical_columns]
print(f"  Categorical indices (for SMOTENC): {categorical_indices}")

non_num = X_train.select_dtypes(exclude=[np.number]).columns.tolist()
if non_num:
    raise ValueError(f"Non-numeric columns remain: {non_num}")
print("✓ All features numeric")

# ── Label mapping + numeric target ──────────────────────────────────────────
label_mapping = LABEL_MAPPING_CONFIG
y_train_numeric = y_train.map(label_mapping)

print("\nConviction label mapping (saved for Code 8c):")
for lbl, num in sorted(label_mapping.items(), key=lambda x:x[1]):
    cnt = (y_train == lbl).sum()
    print(f"    {num} = {lbl:8s}  ({cnt:,} rows, {cnt/len(y_train)*100:.2f}%)")

# ── BASE class weights: FLAT (all 1.0) ──────────────────────────────────────
# Rationale: inverse-frequency weighting distorts predict_proba (it trains the
# model as if every class were 25% likely). The expected-utility decision rule
# needs HONEST probabilities, so cost asymmetry is applied at DECISION time via
# the utility matrix, not at training time. The only training-time tilt is the
# tuned HIGH/MEDIUM weight multipliers (see the hyperparameter grid), which exist
# to correct residual miscalibration — not to encode economics.
n_cls  = len(label_mapping)
total  = len(y_train_numeric)
counts = y_train_numeric.value_counts().to_dict()
CLASS_WEIGHTS = {c: 1.0 for c in range(n_cls)}   # base; multipliers applied per-combo

print("\nBase class weights (FLAT — multipliers tuned per combination):")
for c in range(n_cls):
    lbl = [k for k,v in label_mapping.items() if v==c][0]
    print(f"    {lbl:8s} ({c}): base weight={CLASS_WEIGHTS[c]:.3f}  "
          f"(natural share {counts.get(c,0)/total*100:5.2f}%)")
print()
# Out:
# --------------------------------------------------------------------------------
# DATA QUALITY REPORT — AFTER CLEANING  (train split, 2011-2019)
# --------------------------------------------------------------------------------
# Columns with NaN after : 4 / 256
# Columns with inf after : 0 / 256
# Total NaN after        : 780,163
# Total inf after        : 0
#
# ⚠️  4 columns still have NaN/inf after cleaning:
#               feature cleaning_method  n_nan_after  n_inf_after
# commodity_correlation        keep_nan       276421            0
#      mapped_commodity        keep_nan       276421            0
#   cluster_correlation        keep_nan       222898            0
#               cluster        keep_nan         4423            0
#
# ✓ Saved: data_quality_after.csv, cleaning_report.csv (column-wise before/after + method)
#
# Encoding categorical features (no scaling / no embedding for XGB)...
#   Sector                         → 11 categories
#   cluster                        → 88 categories
#   mapped_commodity               → 8 categories
#   Categorical indices (for SMOTENC): [111, 153, 155]
# ✓ All features numeric
#
# Conviction label mapping (saved for Code 8c):
#     0 = Ignore    (185,004 rows, 64.52%)
#     1 = Low       (13,802 rows, 4.81%)
#     2 = Medium    (24,027 rows, 8.38%)
#     3 = High      (63,906 rows, 22.29%)
#
# Base class weights (FLAT — multipliers tuned per combination):
#     Ignore   (0): base weight=1.000  (natural share 64.52%)
#     Low      (1): base weight=1.000  (natural share  4.81%)
#     Medium   (2): base weight=1.000  (natural share  8.38%)
#     High     (3): base weight=1.000  (natural share 22.29%)

# %% [markdown]
# ## **STEP 7: Scoring Function & Hyperparameter Grid**
#
# **`n_estimators` is part of the grid and early stopping is NOT used** — the final model uses exactly the tree count that was cross-validated, so search and final training are consistent and the validation fold is used only for scoring (no leakage).

# %%
print("-"*80)
print("SCORING FUNCTION + HYPERPARAMETER GRID")
print("-"*80)

# ── LOCKED UTILITY MATRIX ───────────────────────────────────────────────────
# rows = ACTUAL, cols = PREDICTED ; order Ignore0 Low1 Medium2 High3 (Code 7 order)
# DERIVED (not hand-picked) from 4 parameters, constrained to satisfy 3 properties:
#   1. Diagonal dominance — the correct call is the best cell in every row.
#   2. Base-rate default  — with no information the EU rule outputs IGNORE
#                           (a conviction call must be earned by evidence).
#   3. Monotonicity       — EU decisions yield High > Medium > Low > Ignore
#                           bucket returns in 12/12 simulation runs.
UTILITY_MATRIX = np.array([
# Pred: Ignore  Low  Medium  High
    [    2,    -15,   -30,   -46],   # Actual Ignore
    [    0,     10,   -11,   -22],   # Actual Low
    [   -5,      5,    30,   -11],   # Actual Medium
    [  -15,      6,    16,    50],   # Actual High
], dtype=float)

def financial_utility_score(y_true, y_pred):
    U = UTILITY_MATRIX
    return sum(U[t,p] for t,p in zip(y_true, y_pred)) / len(y_true)

def eu_decision(proba, U=None):
    """Expected-utility decision rule.
    proba: (n, n_cls) from predict_proba, columns in class-index order.
    Returns the prediction maximising sum_i P(actual=i) * U(i, j)."""
    if U is None: U = UTILITY_MATRIX
    return (np.asarray(proba) @ U).argmax(axis=1)

# Expected return per ACTUAL class (used only for the monotonicity diagnostic)
LABEL_EXPECTED_RETURN = np.array([-20.0, 10.0, 25.0, 50.0])   # Ignore, Low, Medium, High

def monotonicity_check(y_true, y_pred):
    """Mean label-implied return per PREDICTED bucket; flag High>Medium>Low>Ignore."""
    y_true=np.asarray(y_true); y_pred=np.asarray(y_pred)
    means={}
    for j in range(len(LABEL_EXPECTED_RETURN)):
        m = y_pred==j
        means[j] = float(LABEL_EXPECTED_RETURN[y_true[m]].mean()) if m.sum() else np.nan
    ok = (means[3]>means[2]>means[1]>means[0]) if not any(
         np.isnan(v) for v in means.values()) else False
    return ok, {'ret_pred_Ignore':means[0],'ret_pred_Low':means[1],
                'ret_pred_Medium':means[2],'ret_pred_High':means[3]}

def check_constraints(y_true, y_pred):
    # High is now class 3
    cm = confusion_matrix(y_true, y_pred, labels=[0,1,2,3])
    hp = cm[3,3]/cm[:,3].sum() if cm[:,3].sum()>0 else 0   # High precision
    ig = cm[0,3]/cm[0,:].sum() if cm[0,:].sum()>0 else 0   # Ignore→High
    lh = cm[1,3]/cm[1,:].sum() if cm[1,:].sum()>0 else 0   # Low→High
    # REPORT-ONLY: no longer a pass/fail gate. The utility matrix already prices
    # false Highs (-30 for Ignore->High), so a hard precision gate would fight it.
    # 'met' is retained for backward compatibility but always True.
    met = True
    return met, {'high_precision':hp,'ignore_to_high_rate':ig,'low_to_high_rate':lh}

# n_estimators is TUNED (no early stopping) — see step note
param_grid = {
    'n_estimators'     : [500, 700, 900],
    'max_depth'        : [4, 5, 6, 7, 8, 10, 12, 14, 16],
    'learning_rate'    : [0.1],              #[0.07, 0.1, 0.2],
    'min_child_weight' : [2],                #[2, 3, 5],
    'gamma'            : [0],                #[0.1, 0.2, 0.3],
    'subsample'        : [0.8],              #[0.6, 0.8, 1.0],
    'colsample_bytree' : [0.8],              #[0.6, 0.8, 1.0],
    'reg_alpha'        : [0],                #[0.1, 0.5, 1.0],
    'reg_lambda'       : [2],                #[0.5, 1.0, 1.5],
    # Tuned class-weight multipliers (base weights are flat 1.0).
    # 1.0 is included so "no tilt" can win on merit.
    'HIGH_WEIGHT_MULT'   : [0.75, 1.0, 1.5, 2.0],
    'MEDIUM_WEIGHT_MULT' : [1]               #[1.0, 1.5, 2.0],
}
# Keys that are NOT XGBoost params — stripped before constructing the model
NON_XGB_KEYS = ['HIGH_WEIGHT_MULT', 'MEDIUM_WEIGHT_MULT']

def weights_from_combo(cp):
    """Per-combination class weights: flat base, tuned High/Medium multipliers."""
    w = dict(CLASS_WEIGHTS)                      # {0:1,1:1,2:1,3:1}
    w[2] = w[2] * cp.get('MEDIUM_WEIGHT_MULT', 1.0)
    w[3] = w[3] * cp.get('HIGH_WEIGHT_MULT', 1.0)
    return w

def xgb_params(cp):
    """Strip non-XGBoost keys from a sampled combination."""
    return {k:v for k,v in cp.items() if k not in NON_XGB_KEYS}
param_combinations = list(ParameterSampler(param_grid, n_iter=N_ITER,
                                           random_state=RANDOM_STATE))

fixed_params = {
    'objective'   : 'multi:softprob',   # real probabilities for Code 8c thresholds
    'num_class'   : n_cls,
    'tree_method' : 'hist',
    'device'      : 'cuda',             # ← ADD THIS LINE (uses GPU)
    'random_state': RANDOM_STATE,
    'n_jobs'      : -1,
}

print("Tuned hyperparameters (sampled from grid):")
for p, v in param_grid.items():
    print(f"  {p:18s}: {v}")
print(f"\n  Sampling {N_ITER} combinations")
print(f"\nFixed: {fixed_params}")
print("\nNote: n_estimators is tuned and early stopping is OFF — the final")
print("      model uses exactly the cross-validated tree count.")
print()
# Out:
# --------------------------------------------------------------------------------
# SCORING FUNCTION + HYPERPARAMETER GRID
# --------------------------------------------------------------------------------
# Tuned hyperparameters (sampled from grid):
#   n_estimators      : [500, 700, 900]
#   max_depth         : [4, 5, 6, 7, 8, 10, 12, 14, 16]
#   learning_rate     : [0.1]
#   min_child_weight  : [2]
#   gamma             : [0]
#   subsample         : [0.8]
#   colsample_bytree  : [0.8]
#   reg_alpha         : [0]
#   reg_lambda        : [2]
#   HIGH_WEIGHT_MULT  : [0.75, 1.0, 1.5, 2.0]
#   MEDIUM_WEIGHT_MULT: [1]
#
#   Sampling 500 combinations
#
# Fixed: {'objective': 'multi:softprob', 'num_class': 4, 'tree_method': 'hist', 'device': 'cuda', 'random_state': 42, 'n_jobs': -1}
#
# Note: n_estimators is tuned and early stopping is OFF — the final
#       model uses exactly the cross-validated tree count.

# %% [markdown]
# ## **STEP 8: Walk-Forward Folds + Resampling Plan**

# %%
print("-"*80)
print("WALK-FORWARD FOLDS")
print("-"*80)
date_col = next((c for c in ['date','Date','DATE'] if c in train_df.columns), None)
if date_col is None:
    raise ValueError("No date column in train_df — check Code 8a output")
dates = pd.to_datetime(train_df[date_col])

fold_config = [
    ('2011-01-01','2016-12-31','2017-01-01','2017-12-31'),
    ('2011-01-01','2017-12-31','2018-01-01','2018-12-31'),
    ('2011-01-01','2018-12-31','2019-01-01','2019-12-31'),
]
wf_folds = []
for i,(ts,te,vs,ve) in enumerate(fold_config,1):
    tr = np.where((dates>=ts)&(dates<=te))[0]
    vl = np.where((dates>=vs)&(dates<=ve))[0]
    wf_folds.append((tr,vl))
    print(f"  Fold {i}: Train {ts[:4]}–{te[:4]} ({len(tr):,})  →  Val {vs[:4]} ({len(vl):,})")
N_CV_FOLDS = len(wf_folds)

print("\nResampling plan:")
total_samples = len(y_train_numeric)
current_counts = {c:int((y_train_numeric==c).sum()) for c in range(n_cls)}
classes_to_oversample = {}
for cls, tgt in OVERSAMPLE_TARGETS.items():
    if tgt is None: continue
    tn = int(total_samples*tgt)
    if tn > current_counts[cls]:
        classes_to_oversample[cls] = tn
for cls in range(n_cls):
    lbl = [k for k,v in label_mapping.items() if v==cls][0]
    cur = current_counts[cls]
    if cls in classes_to_oversample:
        act = f"oversample → {classes_to_oversample[cls]:,}"
    else:
        act = "untouched"
    print(f"  {lbl:8s} ({cls}): {cur:,} ({cur/total_samples*100:.1f}%)  {act}")
print()
# Out:
# --------------------------------------------------------------------------------
# WALK-FORWARD FOLDS
# --------------------------------------------------------------------------------
#   Fold 1: Train 2011–2016 (182,013)  →  Val 2017 (33,102)
#   Fold 2: Train 2011–2017 (215,115)  →  Val 2018 (35,174)
#   Fold 3: Train 2011–2018 (250,289)  →  Val 2019 (36,450)
#
# Resampling plan:
#   Ignore   (0): 185,004 (64.5%)  untouched
#   Low      (1): 13,802 (4.8%)  untouched
#   Medium   (2): 24,027 (8.4%)  untouched
#   High     (3): 63,906 (22.3%)  untouched

# %% [markdown]
# ## **STEP 9: Hyperparameter Search (walk-forward, RandomOverSampler)**

# %%
print("="*80)
print("HYPERPARAMETER SEARCH")
print("="*80)

search_results=[]; fold_results=[]
gain_records=[]                 # Req2: (feature, fold, iteration) → gain
combo_model_paths=[]            # Req1: saved per-combo model paths
best_score=-np.inf; best_params=None; best_metrics=None
start=time.time()

# Folder for per-combo models (downloaded as a zip at the end)
COMBO_DIR = os.path.join(OUTPUT_FOLDER, 'combo_models')
os.makedirs(COMBO_DIR, exist_ok=True)

#for it in range(N_ITER):
for it in range(len(param_combinations)):
    cp = param_combinations[it]
    print(f"\n{'='*80}\nITERATION {it+1}/{N_ITER}\n{'='*80}")
    print("  params:", {k:(round(v,3) if isinstance(v,float) else v) for k,v in cp.items()})

    cvs=[]; cvc=[]; chp=[]; cig=[]; clh=[]; cmono=[]
    for fn,(tri,vli) in enumerate(wf_folds,1):
        Xtr=X_train.iloc[tri].copy(); ytr=y_train_numeric.iloc[tri].copy()
        Xvl=X_train.iloc[vli].copy(); yvl=y_train_numeric.iloc[vli].copy()

        need={c:t for c,t in classes_to_oversample.items() if t>ytr.value_counts().get(c,0)}
        if need:
            Xtr,ytr=RandomOverSampler(sampling_strategy=need,
                     random_state=RANDOM_STATE+it+fn).fit_resample(Xtr,ytr)

        # No early stopping; n_estimators comes from cp.
        # xgb_params() strips the tuned weight multipliers (not XGBoost args);
        # weights_from_combo() turns them into this combo's class weights.
        combo_w = weights_from_combo(cp)
        model=xgb.XGBClassifier(**{**fixed_params,**xgb_params(cp)})
        model.fit(Xtr,ytr,sample_weight=ytr.map(combo_w),verbose=False)

        # ── Req2: per-feature GAIN for this fold (all features, zeros explicit) ──
        if COLLECT_GAIN:
            gain_map = model.get_booster().get_score(importance_type='gain')
            # XGBoost keys may be feature names or f0,f1...; map both ways
            for fi_idx, feat in enumerate(feature_columns):
                g = gain_map.get(feat, gain_map.get(f'f{fi_idx}', 0.0))
                gain_records.append({'iteration': it+1, 'fold': fn,
                                     'feature': feat, 'gain': float(g)})

        # DECISION RULE: expected utility on predict_proba (NOT argmax).
        # Selection must use the same rule Code 8c deploys.
        yp_proba=model.predict_proba(Xvl)
        yp=eu_decision(yp_proba)
        sc=financial_utility_score(yvl.values,yp)
        met,mt=check_constraints(yvl.values,yp)      # report-only
        mono_ok, mono_ret = monotonicity_check(yvl.values, yp)
        cvs.append(sc); cvc.append(met); cmono.append(mono_ok)
        chp.append(mt['high_precision']); cig.append(mt['ignore_to_high_rate']); clh.append(mt['low_to_high_rate'])
        fold_results.append({'iteration':it+1,'fold':fn,'score':sc,'meets_constraints':met,
                             'monotonic':mono_ok,**mt,**mono_ret,**cp})
        print(f"  Fold {fn}: score={sc:.2f} mono={'✓' if mono_ok else '✗'} "
              f"HighPrec={mt['high_precision']:.1%} Ign→High={mt['ignore_to_high_rate']:.1%} Low→High={mt['low_to_high_rate']:.1%}")

    ms=np.mean(cvs); allc=all(cvc)
    mhp,mig,mlh=np.mean(chp),np.mean(cig),np.mean(clh)
    print(f"  → mean score={ms:.3f}  constraints_met={'YES' if allc else 'NO'}  "
          f"avgHighPrec={mhp:.1%}")
    n_mono=int(sum(cmono))
    print(f"  → monotonic folds: {n_mono}/{len(cmono)}")
    search_results.append({'iteration':it+1,'mean_cv_score':ms,'all_constraints_met':allc,
        'monotonic_folds':n_mono,'all_folds_monotonic':n_mono==len(cmono),
        'avg_high_precision':mhp,'avg_ignore_to_high_rate':mig,'avg_low_to_high_rate':mlh,**cp})

    # ── Req1: train this combo's FULL-DATA final model and save it ─────────────
    if SAVE_COMBO_MODELS:
        need_full={c:t for c,t in classes_to_oversample.items()
                   if t>y_train_numeric.value_counts().get(c,0)}
        if need_full:
            Xf,yf=RandomOverSampler(sampling_strategy=need_full,
                   random_state=RANDOM_STATE+it).fit_resample(X_train,y_train_numeric)
        else:
            Xf,yf=X_train,y_train_numeric
        combo_model=xgb.XGBClassifier(**{**fixed_params,**xgb_params(cp)})
        combo_model.fit(Xf,yf,sample_weight=yf.map(weights_from_combo(cp)),verbose=False)
        cpath=os.path.join(COMBO_DIR, f'model_combo_{it+1:03d}.pkl')
        with open(cpath,'wb') as _f: pickle.dump(combo_model,_f)
        combo_model_paths.append({'iteration':it+1,'path':cpath,
                                  'mean_cv_score':ms,**cp})
        print(f"  💾 saved combo model: model_combo_{it+1:03d}.pkl")

    if allc and ms>best_score:
        best_score=ms; best_params=cp.copy()
        best_metrics={'avg_high_precision':mhp,'avg_ignore_to_high_rate':mig,'avg_low_to_high_rate':mlh}
        print(f"  🌟 NEW BEST (score={best_score:.3f})")

    el=time.time()-start
    print(f"  elapsed {el/60:.1f} min | ETA {el/(it+1)*(N_ITER-it-1)/60:.1f} min")

search_time=time.time()-start
print(f"\n{'='*80}\nSEARCH COMPLETE in {search_time/60:.1f} min\n{'='*80}")

if best_params is None:
    print("⚠️  No model met all constraints — selecting best by score alone")
    bi=int(np.argmax([r['mean_cv_score'] for r in search_results]))
    br=search_results[bi]
    skip={'iteration','mean_cv_score','all_constraints_met','avg_high_precision',
          'avg_ignore_to_high_rate','avg_low_to_high_rate',
          'monotonic_folds','all_folds_monotonic'}
    best_params={k:v for k,v in br.items() if k not in skip}
    best_score=br['mean_cv_score']
    best_metrics={'avg_high_precision':br['avg_high_precision'],
                  'avg_ignore_to_high_rate':br['avg_ignore_to_high_rate'],
                  'avg_low_to_high_rate':br['avg_low_to_high_rate']}

print("\nBest hyperparameters (incl. tuned n_estimators):")
for p,v in best_params.items():
    print(f"  {p:18s}: {v}")
print(f"\nBest CV score: {best_score:.4f}")
print()
# Out:
# ================================================================================
# HYPERPARAMETER SEARCH
# ================================================================================
#
# ================================================================================
# ITERATION 1/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-3.25 mono=✗ HighPrec=49.2% Ign→High=3.5% Low→High=4.7%
#   Fold 2: score=-4.68 mono=✓ HighPrec=14.7% Ign→High=7.0% Low→High=8.0%
#   Fold 3: score=-2.53 mono=✗ HighPrec=17.3% Ign→High=1.6% Low→High=0.7%
#   → mean score=-3.483  constraints_met=YES  avgHighPrec=27.0%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_001.pkl
#   🌟 NEW BEST (score=-3.483)
#   elapsed 0.6 min | ETA 324.1 min
#
# ================================================================================
# ITERATION 2/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-3.16 mono=✗ HighPrec=48.2% Ign→High=4.1% Low→High=5.7%
#   Fold 2: score=-5.51 mono=✓ HighPrec=12.8% Ign→High=8.5% Low→High=9.3%
#   Fold 3: score=-2.78 mono=✗ HighPrec=19.1% Ign→High=2.4% Low→High=1.6%
#   → mean score=-3.818  constraints_met=YES  avgHighPrec=26.7%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_002.pkl
#   elapsed 1.4 min | ETA 358.4 min
#
# ================================================================================
# ITERATION 3/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-3.09 mono=✗ HighPrec=48.5% Ign→High=4.2% Low→High=6.2%
#   Fold 2: score=-6.08 mono=✓ HighPrec=13.1% Ign→High=10.4% Low→High=11.2%
#   Fold 3: score=-2.85 mono=✗ HighPrec=21.5% Ign→High=2.9% Low→High=2.2%
#   → mean score=-4.006  constraints_met=YES  avgHighPrec=27.7%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_003.pkl
#   elapsed 2.4 min | ETA 394.8 min
#
# ================================================================================
# ITERATION 4/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-3.25 mono=✗ HighPrec=47.9% Ign→High=4.7% Low→High=4.5%
#   Fold 2: score=-4.62 mono=✗ HighPrec=11.5% Ign→High=7.3% Low→High=6.4%
#   Fold 3: score=-2.49 mono=✗ HighPrec=21.8% Ign→High=1.7% Low→High=1.4%
#   → mean score=-3.453  constraints_met=YES  avgHighPrec=27.1%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_004.pkl
#   🌟 NEW BEST (score=-3.453)
#   elapsed 3.1 min | ETA 383.5 min
#
# ================================================================================
# ITERATION 5/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-3.21 mono=✗ HighPrec=47.9% Ign→High=4.7% Low→High=5.1%
#   Fold 2: score=-5.17 mono=✗ HighPrec=12.4% Ign→High=9.1% Low→High=8.1%
#   Fold 3: score=-2.59 mono=✗ HighPrec=23.3% Ign→High=2.4% Low→High=2.2%
#   → mean score=-3.658  constraints_met=YES  avgHighPrec=27.9%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_005.pkl
#   elapsed 4.0 min | ETA 394.3 min
#
# ================================================================================
# ITERATION 6/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.98 mono=✗ HighPrec=51.6% Ign→High=4.1% Low→High=5.0%
#   Fold 2: score=-5.65 mono=✗ HighPrec=12.2% Ign→High=10.6% Low→High=9.4%
#   Fold 3: score=-2.71 mono=✗ HighPrec=23.5% Ign→High=3.0% Low→High=3.2%
#   → mean score=-3.782  constraints_met=YES  avgHighPrec=29.1%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_006.pkl
#   elapsed 5.1 min | ETA 416.9 min
#
# ================================================================================
# ITERATION 7/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.92 mono=✗ HighPrec=56.2% Ign→High=2.9% Low→High=3.3%
#   Fold 2: score=-4.74 mono=✗ HighPrec=12.4% Ign→High=8.5% Low→High=8.0%
#   Fold 3: score=-2.31 mono=✗ HighPrec=28.4% Ign→High=2.0% Low→High=1.9%
#   → mean score=-3.326  constraints_met=YES  avgHighPrec=32.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_007.pkl
#   🌟 NEW BEST (score=-3.326)
#   elapsed 5.9 min | ETA 415.0 min
#
# ================================================================================
# ITERATION 8/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.88 mono=✗ HighPrec=56.0% Ign→High=3.1% Low→High=3.3%
#   Fold 2: score=-5.41 mono=✗ HighPrec=11.8% Ign→High=10.8% Low→High=9.1%
#   Fold 3: score=-2.36 mono=✗ HighPrec=29.5% Ign→High=2.8% Low→High=3.3%
#   → mean score=-3.546  constraints_met=YES  avgHighPrec=32.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_008.pkl
#   elapsed 7.0 min | ETA 428.0 min
#
# ================================================================================
# ITERATION 9/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.83 mono=✗ HighPrec=56.4% Ign→High=3.1% Low→High=3.7%
#   Fold 2: score=-5.71 mono=✗ HighPrec=11.6% Ign→High=12.1% Low→High=10.6%
#   Fold 3: score=-2.44 mono=✗ HighPrec=29.3% Ign→High=3.2% Low→High=3.7%
#   → mean score=-3.659  constraints_met=YES  avgHighPrec=32.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_009.pkl
#   elapsed 8.3 min | ETA 450.5 min
#
# ================================================================================
# ITERATION 10/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.84 mono=✗ HighPrec=55.5% Ign→High=3.4% Low→High=3.5%
#   Fold 2: score=-5.23 mono=✗ HighPrec=12.7% Ign→High=10.7% Low→High=10.9%
#   Fold 3: score=-2.19 mono=✗ HighPrec=30.8% Ign→High=2.1% Low→High=2.4%
#   → mean score=-3.419  constraints_met=YES  avgHighPrec=33.0%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_010.pkl
#   elapsed 9.3 min | ETA 454.4 min
#
# ================================================================================
# ITERATION 11/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.83 mono=✗ HighPrec=54.6% Ign→High=3.5% Low→High=3.9%
#   Fold 2: score=-5.66 mono=✗ HighPrec=12.3% Ign→High=12.5% Low→High=12.0%
#   Fold 3: score=-2.19 mono=✗ HighPrec=31.9% Ign→High=2.5% Low→High=3.9%
#   → mean score=-3.561  constraints_met=YES  avgHighPrec=32.9%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_011.pkl
#   elapsed 10.6 min | ETA 471.5 min
#
# ================================================================================
# ITERATION 12/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.73 mono=✗ HighPrec=56.2% Ign→High=3.3% Low→High=3.5%
#   Fold 2: score=-5.65 mono=✗ HighPrec=11.9% Ign→High=12.8% Low→High=12.6%
#   Fold 3: score=-2.26 mono=✗ HighPrec=31.0% Ign→High=2.8% Low→High=4.3%
#   → mean score=-3.550  constraints_met=YES  avgHighPrec=33.0%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_012.pkl
#   elapsed 12.3 min | ETA 498.6 min
#
# ================================================================================
# ITERATION 13/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.76 mono=✗ HighPrec=58.2% Ign→High=2.7% Low→High=3.4%
#   Fold 2: score=-4.95 mono=✗ HighPrec=10.7% Ign→High=10.9% Low→High=9.2%
#   Fold 3: score=-2.11 mono=✗ HighPrec=31.9% Ign→High=1.7% Low→High=1.7%
#   → mean score=-3.270  constraints_met=YES  avgHighPrec=33.6%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_013.pkl
#   🌟 NEW BEST (score=-3.270)
#   elapsed 13.5 min | ETA 507.4 min
#
# ================================================================================
# ITERATION 14/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.69 mono=✓ HighPrec=59.1% Ign→High=2.9% Low→High=3.0%
#   Fold 2: score=-4.99 mono=✗ HighPrec=10.8% Ign→High=11.9% Low→High=10.3%
#   Fold 3: score=-2.15 mono=✗ HighPrec=30.5% Ign→High=1.9% Low→High=2.3%
#   → mean score=-3.275  constraints_met=YES  avgHighPrec=33.4%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_014.pkl
#   elapsed 15.3 min | ETA 529.4 min
#
# ================================================================================
# ITERATION 15/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.70 mono=✓ HighPrec=59.6% Ign→High=2.7% Low→High=3.1%
#   Fold 2: score=-5.04 mono=✗ HighPrec=10.8% Ign→High=12.5% Low→High=11.2%
#   Fold 3: score=-2.14 mono=✗ HighPrec=30.7% Ign→High=2.0% Low→High=2.2%
#   → mean score=-3.292  constraints_met=YES  avgHighPrec=33.7%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_015.pkl
#   elapsed 17.4 min | ETA 561.1 min
#
# ================================================================================
# ITERATION 16/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.59 mono=✓ HighPrec=61.6% Ign→High=2.4% Low→High=2.8%
#   Fold 2: score=-3.95 mono=✗ HighPrec=13.2% Ign→High=10.0% Low→High=9.1%
#   Fold 3: score=-2.02 mono=✓ HighPrec=34.2% Ign→High=1.5% Low→High=2.2%
#   → mean score=-2.851  constraints_met=YES  avgHighPrec=36.3%
#   → monotonic folds: 2/3
#   💾 saved combo model: model_combo_016.pkl
#   🌟 NEW BEST (score=-2.851)
#   elapsed 19.4 min | ETA 587.1 min
#
# ================================================================================
# ITERATION 17/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.60 mono=✓ HighPrec=61.0% Ign→High=2.6% Low→High=2.6%
#   Fold 2: score=-3.85 mono=✗ HighPrec=13.0% Ign→High=10.2% Low→High=9.7%
#   Fold 3: score=-2.03 mono=✓ HighPrec=33.8% Ign→High=1.6% Low→High=2.3%
#   → mean score=-2.823  constraints_met=YES  avgHighPrec=35.9%
#   → monotonic folds: 2/3
#   💾 saved combo model: model_combo_017.pkl
#   🌟 NEW BEST (score=-2.823)
#   elapsed 22.1 min | ETA 627.8 min
#
# ================================================================================
# ITERATION 18/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.56 mono=✓ HighPrec=61.1% Ign→High=2.7% Low→High=2.7%
#   Fold 2: score=-3.93 mono=✗ HighPrec=12.9% Ign→High=10.6% Low→High=9.8%
#   Fold 3: score=-2.04 mono=✗ HighPrec=33.5% Ign→High=1.6% Low→High=2.2%
#   → mean score=-2.843  constraints_met=YES  avgHighPrec=35.9%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_018.pkl
#   elapsed 25.4 min | ETA 678.8 min
#
# ================================================================================
# ITERATION 19/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.53 mono=✓ HighPrec=65.7% Ign→High=1.9% Low→High=2.3%
#   Fold 2: score=-3.16 mono=✗ HighPrec=13.0% Ign→High=8.6% Low→High=8.9%
#   Fold 3: score=-1.96 mono=✗ HighPrec=34.0% Ign→High=1.1% Low→High=1.2%
#   → mean score=-2.552  constraints_met=YES  avgHighPrec=37.5%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_019.pkl
#   🌟 NEW BEST (score=-2.552)
#   elapsed 28.4 min | ETA 718.9 min
#
# ================================================================================
# ITERATION 20/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.48 mono=✓ HighPrec=65.7% Ign→High=2.0% Low→High=2.3%
#   Fold 2: score=-3.18 mono=✗ HighPrec=13.0% Ign→High=8.9% Low→High=8.2%
#   Fold 3: score=-1.98 mono=✗ HighPrec=33.7% Ign→High=1.2% Low→High=1.1%
#   → mean score=-2.550  constraints_met=YES  avgHighPrec=37.5%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_020.pkl
#   🌟 NEW BEST (score=-2.550)
#   elapsed 32.2 min | ETA 772.9 min
#
# ================================================================================
# ITERATION 21/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.48 mono=✓ HighPrec=65.2% Ign→High=2.1% Low→High=2.4%
#   Fold 2: score=-3.28 mono=✗ HighPrec=12.7% Ign→High=9.2% Low→High=8.4%
#   Fold 3: score=-2.00 mono=✗ HighPrec=33.0% Ign→High=1.2% Low→High=1.2%
#   → mean score=-2.586  constraints_met=YES  avgHighPrec=37.0%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_021.pkl
#   elapsed 36.7 min | ETA 836.4 min
#
# ================================================================================
# ITERATION 22/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.65 mono=✓ HighPrec=62.4% Ign→High=2.3% Low→High=2.4%
#   Fold 2: score=-3.17 mono=✗ HighPrec=12.1% Ign→High=8.6% Low→High=8.8%
#   Fold 3: score=-2.05 mono=✗ HighPrec=28.1% Ign→High=1.1% Low→High=1.1%
#   → mean score=-2.625  constraints_met=YES  avgHighPrec=34.2%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_022.pkl
#   elapsed 40.6 min | ETA 882.6 min
#
# ================================================================================
# ITERATION 23/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.64 mono=✓ HighPrec=62.5% Ign→High=2.3% Low→High=2.5%
#   Fold 2: score=-3.21 mono=✗ HighPrec=12.4% Ign→High=8.9% Low→High=8.7%
#   Fold 3: score=-2.06 mono=✗ HighPrec=28.1% Ign→High=1.2% Low→High=1.2%
#   → mean score=-2.639  constraints_met=YES  avgHighPrec=34.3%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_023.pkl
#   elapsed 45.4 min | ETA 942.3 min
#
# ================================================================================
# ITERATION 24/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.63 mono=✓ HighPrec=62.2% Ign→High=2.4% Low→High=2.5%
#   Fold 2: score=-3.27 mono=✗ HighPrec=12.4% Ign→High=9.1% Low→High=8.7%
#   Fold 3: score=-2.09 mono=✗ HighPrec=27.8% Ign→High=1.3% Low→High=1.4%
#   → mean score=-2.662  constraints_met=YES  avgHighPrec=34.1%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_024.pkl
#   elapsed 51.0 min | ETA 1011.9 min
#
# ================================================================================
# ITERATION 25/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.59 mono=✓ HighPrec=65.0% Ign→High=2.0% Low→High=2.6%
#   Fold 2: score=-2.63 mono=✗ HighPrec=12.6% Ign→High=7.2% Low→High=7.4%
#   Fold 3: score=-1.99 mono=✗ HighPrec=32.9% Ign→High=0.9% Low→High=1.0%
#   → mean score=-2.405  constraints_met=YES  avgHighPrec=36.8%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_025.pkl
#   🌟 NEW BEST (score=-2.405)
#   elapsed 55.6 min | ETA 1055.6 min
#
# ================================================================================
# ITERATION 26/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.58 mono=✓ HighPrec=64.5% Ign→High=2.1% Low→High=2.6%
#   Fold 2: score=-2.62 mono=✗ HighPrec=13.1% Ign→High=7.3% Low→High=7.2%
#   Fold 3: score=-2.02 mono=✗ HighPrec=31.8% Ign→High=1.0% Low→High=1.0%
#   → mean score=-2.407  constraints_met=YES  avgHighPrec=36.5%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_026.pkl
#   elapsed 61.0 min | ETA 1112.0 min
#
# ================================================================================
# ITERATION 27/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 0.75}
#   Fold 1: score=-2.57 mono=✓ HighPrec=63.9% Ign→High=2.2% Low→High=2.6%
#   Fold 2: score=-2.67 mono=✗ HighPrec=12.9% Ign→High=7.5% Low→High=7.0%
#   Fold 3: score=-2.06 mono=✗ HighPrec=29.9% Ign→High=1.1% Low→High=1.3%
#   → mean score=-2.434  constraints_met=YES  avgHighPrec=35.6%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_027.pkl
#   elapsed 67.2 min | ETA 1177.8 min
#
# ================================================================================
# ITERATION 28/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.98 mono=✗ HighPrec=48.8% Ign→High=5.1% Low→High=6.4%
#   Fold 2: score=-5.94 mono=✗ HighPrec=12.3% Ign→High=10.5% Low→High=9.6%
#   Fold 3: score=-2.52 mono=✗ HighPrec=27.0% Ign→High=3.0% Low→High=3.5%
#   → mean score=-3.816  constraints_met=YES  avgHighPrec=29.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_028.pkl
#   elapsed 67.9 min | ETA 1143.9 min
#
# ================================================================================
# ITERATION 29/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-3.00 mono=✗ HighPrec=47.7% Ign→High=5.4% Low→High=6.9%
#   Fold 2: score=-6.52 mono=✗ HighPrec=12.3% Ign→High=12.1% Low→High=10.5%
#   Fold 3: score=-2.66 mono=✗ HighPrec=28.0% Ign→High=3.8% Low→High=5.1%
#   → mean score=-4.061  constraints_met=YES  avgHighPrec=29.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_029.pkl
#   elapsed 68.6 min | ETA 1114.6 min
#
# ================================================================================
# ITERATION 30/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.87 mono=✗ HighPrec=49.7% Ign→High=4.9% Low→High=7.0%
#   Fold 2: score=-7.17 mono=✗ HighPrec=11.8% Ign→High=13.8% Low→High=12.3%
#   Fold 3: score=-2.74 mono=✗ HighPrec=28.9% Ign→High=4.6% Low→High=6.0%
#   → mean score=-4.260  constraints_met=YES  avgHighPrec=30.1%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_030.pkl
#   elapsed 69.6 min | ETA 1089.6 min
#
# ================================================================================
# ITERATION 31/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-3.28 mono=✗ HighPrec=46.4% Ign→High=5.8% Low→High=6.0%
#   Fold 2: score=-6.53 mono=✗ HighPrec=11.5% Ign→High=11.5% Low→High=10.0%
#   Fold 3: score=-2.56 mono=✗ HighPrec=25.8% Ign→High=2.5% Low→High=2.4%
#   → mean score=-4.120  constraints_met=YES  avgHighPrec=27.9%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_031.pkl
#   elapsed 70.3 min | ETA 1063.0 min
#
# ================================================================================
# ITERATION 32/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-3.41 mono=✗ HighPrec=44.5% Ign→High=6.2% Low→High=6.4%
#   Fold 2: score=-7.13 mono=✗ HighPrec=10.5% Ign→High=13.4% Low→High=11.4%
#   Fold 3: score=-2.62 mono=✗ HighPrec=28.6% Ign→High=3.4% Low→High=4.4%
#   → mean score=-4.386  constraints_met=YES  avgHighPrec=27.9%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_032.pkl
#   elapsed 71.1 min | ETA 1040.5 min
#
# ================================================================================
# ITERATION 33/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-3.40 mono=✗ HighPrec=44.7% Ign→High=6.2% Low→High=6.8%
#   Fold 2: score=-7.49 mono=✗ HighPrec=10.7% Ign→High=14.9% Low→High=11.9%
#   Fold 3: score=-2.68 mono=✗ HighPrec=30.2% Ign→High=4.3% Low→High=5.5%
#   → mean score=-4.523  constraints_met=YES  avgHighPrec=28.5%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_033.pkl
#   elapsed 72.2 min | ETA 1022.1 min
#
# ================================================================================
# ITERATION 34/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.92 mono=✗ HighPrec=51.0% Ign→High=4.6% Low→High=5.6%
#   Fold 2: score=-6.82 mono=✗ HighPrec=10.1% Ign→High=14.0% Low→High=13.0%
#   Fold 3: score=-2.58 mono=✗ HighPrec=29.6% Ign→High=3.5% Low→High=3.7%
#   → mean score=-4.108  constraints_met=YES  avgHighPrec=30.3%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_034.pkl
#   elapsed 73.0 min | ETA 1001.2 min
#
# ================================================================================
# ITERATION 35/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.90 mono=✗ HighPrec=51.8% Ign→High=4.4% Low→High=5.3%
#   Fold 2: score=-6.86 mono=✗ HighPrec=10.3% Ign→High=14.9% Low→High=13.2%
#   Fold 3: score=-2.66 mono=✗ HighPrec=29.0% Ign→High=4.1% Low→High=4.1%
#   → mean score=-4.140  constraints_met=YES  avgHighPrec=30.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_035.pkl
#   elapsed 74.1 min | ETA 984.6 min
#
# ================================================================================
# ITERATION 36/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.87 mono=✗ HighPrec=51.4% Ign→High=4.7% Low→High=5.9%
#   Fold 2: score=-7.00 mono=✗ HighPrec=10.0% Ign→High=15.6% Low→High=13.6%
#   Fold 3: score=-2.60 mono=✗ HighPrec=30.4% Ign→High=4.3% Low→High=4.0%
#   → mean score=-4.158  constraints_met=YES  avgHighPrec=30.6%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_036.pkl
#   elapsed 75.4 min | ETA 971.8 min
#
# ================================================================================
# ITERATION 37/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.81 mono=✗ HighPrec=53.0% Ign→High=4.1% Low→High=4.8%
#   Fold 2: score=-5.35 mono=✗ HighPrec=11.4% Ign→High=10.7% Low→High=8.9%
#   Fold 3: score=-2.26 mono=✗ HighPrec=33.0% Ign→High=3.2% Low→High=3.3%
#   → mean score=-3.469  constraints_met=YES  avgHighPrec=32.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_037.pkl
#   elapsed 76.4 min | ETA 956.1 min
#
# ================================================================================
# ITERATION 38/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.74 mono=✗ HighPrec=54.3% Ign→High=4.0% Low→High=4.3%
#   Fold 2: score=-5.20 mono=✗ HighPrec=11.8% Ign→High=11.1% Low→High=10.2%
#   Fold 3: score=-2.35 mono=✗ HighPrec=31.6% Ign→High=3.5% Low→High=3.8%
#   → mean score=-3.430  constraints_met=YES  avgHighPrec=32.6%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_038.pkl
#   elapsed 77.7 min | ETA 944.8 min
#
# ================================================================================
# ITERATION 39/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.71 mono=✗ HighPrec=55.0% Ign→High=3.8% Low→High=4.6%
#   Fold 2: score=-5.30 mono=✗ HighPrec=11.5% Ign→High=12.0% Low→High=11.1%
#   Fold 3: score=-2.43 mono=✗ HighPrec=30.5% Ign→High=3.6% Low→High=3.9%
#   → mean score=-3.480  constraints_met=YES  avgHighPrec=32.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_039.pkl
#   elapsed 79.3 min | ETA 937.5 min
#
# ================================================================================
# ITERATION 40/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.69 mono=✗ HighPrec=60.1% Ign→High=2.6% Low→High=3.2%
#   Fold 2: score=-5.75 mono=✗ HighPrec=11.7% Ign→High=13.6% Low→High=12.2%
#   Fold 3: score=-2.20 mono=✗ HighPrec=30.7% Ign→High=2.3% Low→High=2.9%
#   → mean score=-3.548  constraints_met=YES  avgHighPrec=34.2%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_040.pkl
#   elapsed 80.6 min | ETA 926.6 min
#
# ================================================================================
# ITERATION 41/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.64 mono=✗ HighPrec=59.8% Ign→High=2.7% Low→High=3.4%
#   Fold 2: score=-5.65 mono=✗ HighPrec=11.4% Ign→High=14.0% Low→High=13.0%
#   Fold 3: score=-2.26 mono=✗ HighPrec=29.3% Ign→High=2.4% Low→High=2.7%
#   → mean score=-3.516  constraints_met=YES  avgHighPrec=33.5%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_041.pkl
#   elapsed 82.2 min | ETA 920.6 min
#
# ================================================================================
# ITERATION 42/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.59 mono=✗ HighPrec=60.5% Ign→High=2.7% Low→High=3.2%
#   Fold 2: score=-5.62 mono=✗ HighPrec=11.0% Ign→High=14.4% Low→High=13.9%
#   Fold 3: score=-2.25 mono=✗ HighPrec=29.7% Ign→High=2.5% Low→High=2.5%
#   → mean score=-3.486  constraints_met=YES  avgHighPrec=33.7%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_042.pkl
#   elapsed 84.3 min | ETA 919.4 min
#
# ================================================================================
# ITERATION 43/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.49 mono=✓ HighPrec=62.4% Ign→High=2.5% Low→High=2.8%
#   Fold 2: score=-4.23 mono=✗ HighPrec=11.8% Ign→High=10.7% Low→High=8.2%
#   Fold 3: score=-2.08 mono=✗ HighPrec=34.4% Ign→High=2.1% Low→High=2.3%
#   → mean score=-2.933  constraints_met=YES  avgHighPrec=36.2%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_043.pkl
#   elapsed 86.4 min | ETA 917.9 min
#
# ================================================================================
# ITERATION 44/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.47 mono=✓ HighPrec=62.6% Ign→High=2.6% Low→High=2.7%
#   Fold 2: score=-4.20 mono=✗ HighPrec=11.8% Ign→High=11.1% Low→High=8.9%
#   Fold 3: score=-2.11 mono=✗ HighPrec=32.5% Ign→High=2.1% Low→High=2.5%
#   → mean score=-2.927  constraints_met=YES  avgHighPrec=35.6%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_044.pkl
#   elapsed 89.0 min | ETA 922.8 min
#
# ================================================================================
# ITERATION 45/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.43 mono=✓ HighPrec=62.3% Ign→High=2.7% Low→High=2.9%
#   Fold 2: score=-4.02 mono=✗ HighPrec=12.4% Ign→High=10.9% Low→High=9.1%
#   Fold 3: score=-2.15 mono=✗ HighPrec=31.4% Ign→High=2.2% Low→High=2.8%
#   → mean score=-2.865  constraints_met=YES  avgHighPrec=35.3%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_045.pkl
#   elapsed 92.3 min | ETA 933.1 min
#
# ================================================================================
# ITERATION 46/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.39 mono=✗ HighPrec=66.8% Ign→High=2.0% Low→High=2.4%
#   Fold 2: score=-3.45 mono=✗ HighPrec=12.7% Ign→High=9.3% Low→High=8.9%
#   Fold 3: score=-1.97 mono=✗ HighPrec=34.7% Ign→High=1.2% Low→High=1.2%
#   → mean score=-2.603  constraints_met=YES  avgHighPrec=38.1%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_046.pkl
#   elapsed 95.4 min | ETA 941.3 min
#
# ================================================================================
# ITERATION 47/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.37 mono=✓ HighPrec=66.8% Ign→High=2.0% Low→High=2.4%
#   Fold 2: score=-3.51 mono=✗ HighPrec=13.0% Ign→High=9.6% Low→High=9.3%
#   Fold 3: score=-2.01 mono=✗ HighPrec=33.0% Ign→High=1.3% Low→High=1.4%
#   → mean score=-2.630  constraints_met=YES  avgHighPrec=37.6%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_047.pkl
#   elapsed 99.2 min | ETA 956.4 min
#
# ================================================================================
# ITERATION 48/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.37 mono=✓ HighPrec=66.0% Ign→High=2.1% Low→High=2.4%
#   Fold 2: score=-3.56 mono=✗ HighPrec=12.9% Ign→High=9.8% Low→High=9.3%
#   Fold 3: score=-2.02 mono=✓ HighPrec=32.7% Ign→High=1.4% Low→High=1.4%
#   → mean score=-2.649  constraints_met=YES  avgHighPrec=37.2%
#   → monotonic folds: 2/3
#   💾 saved combo model: model_combo_048.pkl
#   elapsed 103.8 min | ETA 977.1 min
#
# ================================================================================
# ITERATION 49/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.50 mono=✓ HighPrec=62.7% Ign→High=2.5% Low→High=2.7%
#   Fold 2: score=-3.19 mono=✗ HighPrec=11.9% Ign→High=8.7% Low→High=9.1%
#   Fold 3: score=-1.97 mono=✗ HighPrec=33.3% Ign→High=1.0% Low→High=1.2%
#   → mean score=-2.557  constraints_met=YES  avgHighPrec=36.0%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_049.pkl
#   elapsed 107.7 min | ETA 991.6 min
#
# ================================================================================
# ITERATION 50/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.50 mono=✓ HighPrec=62.2% Ign→High=2.6% Low→High=2.7%
#   Fold 2: score=-3.25 mono=✗ HighPrec=11.9% Ign→High=8.9% Low→High=9.3%
#   Fold 3: score=-1.98 mono=✗ HighPrec=32.8% Ign→High=1.1% Low→High=1.5%
#   → mean score=-2.575  constraints_met=YES  avgHighPrec=35.6%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_050.pkl
#   elapsed 112.6 min | ETA 1013.2 min
#
# ================================================================================
# ITERATION 51/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.48 mono=✓ HighPrec=61.9% Ign→High=2.7% Low→High=2.8%
#   Fold 2: score=-3.25 mono=✗ HighPrec=12.0% Ign→High=8.9% Low→High=9.4%
#   Fold 3: score=-1.99 mono=✗ HighPrec=32.9% Ign→High=1.2% Low→High=1.2%
#   → mean score=-2.572  constraints_met=YES  avgHighPrec=35.6%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_051.pkl
#   elapsed 118.2 min | ETA 1040.5 min
#
# ================================================================================
# ITERATION 52/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.67 mono=✗ HighPrec=58.5% Ign→High=3.0% Low→High=3.0%
#   Fold 2: score=-2.85 mono=✗ HighPrec=12.6% Ign→High=7.8% Low→High=7.9%
#   Fold 3: score=-2.00 mono=✗ HighPrec=31.3% Ign→High=0.9% Low→High=1.2%
#   → mean score=-2.507  constraints_met=YES  avgHighPrec=34.2%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_052.pkl
#   elapsed 122.8 min | ETA 1057.6 min
#
# ================================================================================
# ITERATION 53/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.66 mono=✗ HighPrec=58.6% Ign→High=3.0% Low→High=3.1%
#   Fold 2: score=-2.90 mono=✗ HighPrec=12.5% Ign→High=8.0% Low→High=8.3%
#   Fold 3: score=-2.02 mono=✗ HighPrec=30.5% Ign→High=1.0% Low→High=1.4%
#   → mean score=-2.524  constraints_met=YES  avgHighPrec=33.9%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_053.pkl
#   elapsed 128.2 min | ETA 1081.6 min
#
# ================================================================================
# ITERATION 54/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.0}
#   Fold 1: score=-2.61 mono=✗ HighPrec=59.4% Ign→High=3.0% Low→High=3.0%
#   Fold 2: score=-2.92 mono=✗ HighPrec=12.4% Ign→High=8.1% Low→High=8.0%
#   Fold 3: score=-2.04 mono=✗ HighPrec=30.1% Ign→High=1.0% Low→High=1.6%
#   → mean score=-2.521  constraints_met=YES  avgHighPrec=34.0%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_054.pkl
#   elapsed 134.5 min | ETA 1111.2 min
#
# ================================================================================
# ITERATION 55/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.5}
#   Fold 1: score=-2.88 mono=✗ HighPrec=46.1% Ign→High=7.7% Low→High=10.2%
#   Fold 2: score=-12.79 mono=✗ HighPrec=9.8% Ign→High=29.7% Low→High=25.6%
#   Fold 3: score=-3.56 mono=✗ HighPrec=28.1% Ign→High=8.6% Low→High=11.2%
#   → mean score=-6.409  constraints_met=YES  avgHighPrec=28.0%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_055.pkl
#   elapsed 135.2 min | ETA 1093.6 min
#
# ================================================================================
# ITERATION 56/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.5}
#   Fold 1: score=-2.83 mono=✗ HighPrec=46.6% Ign→High=7.3% Low→High=10.3%
#   Fold 2: score=-12.09 mono=✗ HighPrec=10.0% Ign→High=28.4% Low→High=25.1%
#   Fold 3: score=-3.75 mono=✗ HighPrec=28.3% Ign→High=9.7% Low→High=12.1%
#   → mean score=-6.226  constraints_met=YES  avgHighPrec=28.3%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_056.pkl
#   elapsed 136.0 min | ETA 1077.9 min
#
# ================================================================================
# ITERATION 57/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.5}
#   Fold 1: score=-2.90 mono=✗ HighPrec=45.8% Ign→High=7.1% Low→High=10.7%
#   Fold 2: score=-10.95 mono=✗ HighPrec=10.5% Ign→High=25.6% Low→High=22.5%
#   Fold 3: score=-3.76 mono=✗ HighPrec=29.2% Ign→High=10.4% Low→High=13.6%
#   → mean score=-5.873  constraints_met=YES  avgHighPrec=28.5%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_057.pkl
#   elapsed 136.9 min | ETA 1064.0 min
#
# ================================================================================
# ITERATION 58/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.5}
#   Fold 1: score=-2.75 mono=✗ HighPrec=47.2% Ign→High=7.6% Low→High=10.1%
#   Fold 2: score=-9.75 mono=✗ HighPrec=10.1% Ign→High=22.5% Low→High=21.6%
#   Fold 3: score=-3.26 mono=✗ HighPrec=29.2% Ign→High=7.1% Low→High=7.4%
#   → mean score=-5.258  constraints_met=YES  avgHighPrec=28.8%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_058.pkl
#   elapsed 137.6 min | ETA 1048.8 min
#
# ================================================================================
# ITERATION 59/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.5}
#   Fold 1: score=-2.84 mono=✗ HighPrec=47.0% Ign→High=7.4% Low→High=9.5%
#   Fold 2: score=-9.04 mono=✗ HighPrec=10.6% Ign→High=20.8% Low→High=20.1%
#   Fold 3: score=-3.17 mono=✗ HighPrec=30.0% Ign→High=7.1% Low→High=7.2%
#   → mean score=-5.018  constraints_met=YES  avgHighPrec=29.2%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_059.pkl
#   elapsed 138.5 min | ETA 1035.3 min
#
# ================================================================================
# ITERATION 60/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 1.5}
#   Fold 1: score=-2.85 mono=✗ HighPrec=47.3% Ign→High=6.9% Low→High=8.8%
#   Fold 2: score=-8.66 mono=✗ HighPrec=10.7% Ign→High=20.1% Low→High=18.8%
#   Fold 3: score=-3.13 mono=✗ HighPrec=30.3% Ign→High=7.3% Low→High=7.3%
#   → mean score=-4.880  constraints_met=YES  avgHighPrec=29.5%
# ...
#   Fold 2: score=-10.72 mono=✗ HighPrec=10.5% Ign→High=26.9% Low→High=24.6%
#   Fold 3: score=-3.10 mono=✗ HighPrec=30.6% Ign→High=8.3% Low→High=10.2%
#   → mean score=-5.547  constraints_met=YES  avgHighPrec=29.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_089.pkl
#   elapsed 209.4 min | ETA 967.1 min
#
# ================================================================================
# ITERATION 90/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 6, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.70 mono=✗ HighPrec=48.8% Ign→High=7.4% Low→High=8.7%
#   Fold 2: score=-9.92 mono=✗ HighPrec=10.4% Ign→High=24.7% Low→High=22.6%
#   Fold 3: score=-2.96 mono=✗ HighPrec=31.4% Ign→High=7.7% Low→High=9.1%
#   → mean score=-5.192  constraints_met=YES  avgHighPrec=30.2%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_090.pkl
#   elapsed 210.7 min | ETA 959.9 min
#
# ================================================================================
# ITERATION 91/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.73 mono=✗ HighPrec=47.7% Ign→High=7.9% Low→High=8.9%
#   Fold 2: score=-8.65 mono=✗ HighPrec=10.4% Ign→High=21.2% Low→High=18.5%
#   Fold 3: score=-2.74 mono=✗ HighPrec=32.2% Ign→High=7.6% Low→High=9.9%
#   → mean score=-4.707  constraints_met=YES  avgHighPrec=30.1%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_091.pkl
#   elapsed 211.7 min | ETA 951.6 min
#
# ================================================================================
# ITERATION 92/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.63 mono=✗ HighPrec=49.0% Ign→High=7.3% Low→High=8.3%
#   Fold 2: score=-8.19 mono=✗ HighPrec=10.2% Ign→High=20.3% Low→High=17.6%
#   Fold 3: score=-2.71 mono=✗ HighPrec=31.7% Ign→High=6.5% Low→High=8.4%
#   → mean score=-4.508  constraints_met=YES  avgHighPrec=30.3%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_092.pkl
#   elapsed 213.0 min | ETA 944.8 min
#
# ================================================================================
# ITERATION 93/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.62 mono=✗ HighPrec=50.0% Ign→High=6.6% Low→High=7.5%
#   Fold 2: score=-7.83 mono=✗ HighPrec=10.3% Ign→High=19.8% Low→High=17.5%
#   Fold 3: score=-2.65 mono=✗ HighPrec=31.5% Ign→High=5.9% Low→High=7.6%
#   → mean score=-4.368  constraints_met=YES  avgHighPrec=30.6%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_093.pkl
#   elapsed 214.7 min | ETA 939.4 min
#
# ================================================================================
# ITERATION 94/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.69 mono=✗ HighPrec=49.5% Ign→High=7.0% Low→High=7.5%
#   Fold 2: score=-8.15 mono=✗ HighPrec=10.3% Ign→High=20.9% Low→High=19.5%
#   Fold 3: score=-2.51 mono=✗ HighPrec=33.2% Ign→High=6.0% Low→High=5.5%
#   → mean score=-4.451  constraints_met=YES  avgHighPrec=31.0%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_094.pkl
#   elapsed 215.9 min | ETA 932.7 min
#
# ================================================================================
# ITERATION 95/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.52 mono=✗ HighPrec=51.7% Ign→High=6.0% Low→High=7.0%
#   Fold 2: score=-7.45 mono=✗ HighPrec=10.6% Ign→High=19.5% Low→High=18.2%
#   Fold 3: score=-2.50 mono=✗ HighPrec=31.9% Ign→High=5.4% Low→High=5.2%
#   → mean score=-4.156  constraints_met=YES  avgHighPrec=31.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_095.pkl
#   elapsed 217.6 min | ETA 927.8 min
#
# ================================================================================
# ITERATION 96/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 8, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.50 mono=✗ HighPrec=53.0% Ign→High=5.5% Low→High=6.2%
#   Fold 2: score=-7.06 mono=✗ HighPrec=11.0% Ign→High=18.6% Low→High=17.4%
#   Fold 3: score=-2.43 mono=✗ HighPrec=31.8% Ign→High=4.8% Low→High=4.6%
#   → mean score=-3.999  constraints_met=YES  avgHighPrec=31.9%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_096.pkl
#   elapsed 219.7 min | ETA 924.7 min
#
# ================================================================================
# ITERATION 97/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.47 mono=✗ HighPrec=55.9% Ign→High=4.4% Low→High=4.4%
#   Fold 2: score=-5.69 mono=✗ HighPrec=11.0% Ign→High=15.1% Low→High=13.1%
#   Fold 3: score=-2.14 mono=✗ HighPrec=33.8% Ign→High=2.7% Low→High=2.6%
#   → mean score=-3.435  constraints_met=YES  avgHighPrec=33.6%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_097.pkl
#   elapsed 221.8 min | ETA 921.5 min
#
# ================================================================================
# ITERATION 98/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.46 mono=✗ HighPrec=56.5% Ign→High=4.1% Low→High=4.4%
#   Fold 2: score=-5.17 mono=✗ HighPrec=11.3% Ign→High=14.0% Low→High=12.8%
#   Fold 3: score=-2.18 mono=✗ HighPrec=31.8% Ign→High=2.5% Low→High=2.6%
#   → mean score=-3.271  constraints_met=YES  avgHighPrec=33.2%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_098.pkl
#   elapsed 224.5 min | ETA 921.1 min
#
# ================================================================================
# ITERATION 99/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 10, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.39 mono=✓ HighPrec=57.4% Ign→High=4.1% Low→High=4.1%
#   Fold 2: score=-5.16 mono=✗ HighPrec=10.9% Ign→High=14.0% Low→High=12.4%
#   Fold 3: score=-2.20 mono=✗ HighPrec=30.8% Ign→High=2.5% Low→High=2.7%
#   → mean score=-3.251  constraints_met=YES  avgHighPrec=33.0%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_099.pkl
#   elapsed 227.8 min | ETA 922.8 min
#
# ================================================================================
# ITERATION 100/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.34 mono=✗ HighPrec=63.5% Ign→High=2.7% Low→High=3.0%
#   Fold 2: score=-4.91 mono=✗ HighPrec=11.2% Ign→High=13.6% Low→High=12.3%
#   Fold 3: score=-2.14 mono=✗ HighPrec=31.4% Ign→High=2.1% Low→High=2.3%
#   → mean score=-3.132  constraints_met=YES  avgHighPrec=35.4%
#   → monotonic folds: 0/3
#   💾 saved combo model: model_combo_100.pkl
#   elapsed 231.0 min | ETA 923.9 min
#
# ================================================================================
# ITERATION 101/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.33 mono=✓ HighPrec=63.7% Ign→High=2.7% Low→High=3.0%
#   Fold 2: score=-4.96 mono=✗ HighPrec=11.1% Ign→High=13.9% Low→High=12.2%
#   Fold 3: score=-2.14 mono=✗ HighPrec=31.2% Ign→High=2.0% Low→High=2.3%
#   → mean score=-3.145  constraints_met=YES  avgHighPrec=35.3%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_101.pkl
#   elapsed 234.9 min | ETA 928.0 min
#
# ================================================================================
# ITERATION 102/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.33 mono=✓ HighPrec=63.5% Ign→High=2.7% Low→High=3.0%
#   Fold 2: score=-5.02 mono=✗ HighPrec=11.1% Ign→High=14.0% Low→High=12.1%
#   Fold 3: score=-2.19 mono=✗ HighPrec=29.4% Ign→High=2.2% Low→High=2.2%
#   → mean score=-3.180  constraints_met=YES  avgHighPrec=34.7%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_102.pkl
#   elapsed 239.5 min | ETA 934.6 min
#
# ================================================================================
# ITERATION 103/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.45 mono=✓ HighPrec=60.0% Ign→High=3.1% Low→High=3.7%
#   Fold 2: score=-4.29 mono=✗ HighPrec=12.6% Ign→High=12.3% Low→High=11.1%
#   Fold 3: score=-2.12 mono=✗ HighPrec=30.5% Ign→High=1.8% Low→High=1.4%
#   → mean score=-2.950  constraints_met=YES  avgHighPrec=34.4%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_103.pkl
#   elapsed 243.6 min | ETA 938.9 min
#
# ================================================================================
# ITERATION 104/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.42 mono=✓ HighPrec=60.3% Ign→High=3.1% Low→High=3.6%
#   Fold 2: score=-4.23 mono=✗ HighPrec=12.6% Ign→High=12.2% Low→High=11.4%
#   Fold 3: score=-2.14 mono=✗ HighPrec=29.9% Ign→High=1.9% Low→High=1.4%
#   → mean score=-2.929  constraints_met=YES  avgHighPrec=34.3%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_104.pkl
#   elapsed 248.5 min | ETA 946.4 min
#
# ================================================================================
# ITERATION 105/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 14, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.41 mono=✓ HighPrec=60.5% Ign→High=3.1% Low→High=3.3%
#   Fold 2: score=-4.17 mono=✗ HighPrec=12.9% Ign→High=12.1% Low→High=11.7%
#   Fold 3: score=-2.15 mono=✗ HighPrec=29.8% Ign→High=1.9% Low→High=1.5%
#   → mean score=-2.909  constraints_met=YES  avgHighPrec=34.4%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_105.pkl
#   elapsed 254.2 min | ETA 956.5 min
#
# ================================================================================
# ITERATION 106/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 500, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.59 mono=✓ HighPrec=57.7% Ign→High=3.4% Low→High=4.0%
#   Fold 2: score=-4.30 mono=✗ HighPrec=12.0% Ign→High=12.4% Low→High=13.0%
#   Fold 3: score=-2.17 mono=✗ HighPrec=26.3% Ign→High=1.6% Low→High=1.9%
#   → mean score=-3.020  constraints_met=YES  avgHighPrec=32.0%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_106.pkl
#   elapsed 258.9 min | ETA 962.4 min
#
# ================================================================================
# ITERATION 107/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 700, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.55 mono=✓ HighPrec=58.1% Ign→High=3.4% Low→High=4.0%
#   Fold 2: score=-4.32 mono=✗ HighPrec=12.2% Ign→High=12.5% Low→High=12.3%
#   Fold 3: score=-2.16 mono=✗ HighPrec=27.1% Ign→High=1.7% Low→High=2.0%
#   → mean score=-3.006  constraints_met=YES  avgHighPrec=32.5%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_107.pkl
#   elapsed 264.5 min | ETA 971.5 min
#
# ================================================================================
# ITERATION 108/500
# ================================================================================
#   params: {'subsample': 0.8, 'reg_lambda': 2, 'reg_alpha': 0, 'n_estimators': 900, 'min_child_weight': 2, 'max_depth': 16, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.8, 'MEDIUM_WEIGHT_MULT': 1, 'HIGH_WEIGHT_MULT': 2.0}
#   Fold 1: score=-2.55 mono=✓ HighPrec=58.3% Ign→High=3.3% Low→High=3.8%
#   Fold 2: score=-4.25 mono=✗ HighPrec=12.2% Ign→High=12.4% Low→High=12.1%
#   Fold 3: score=-2.18 mono=✗ HighPrec=27.1% Ign→High=1.7% Low→High=2.0%
#   → mean score=-2.994  constraints_met=YES  avgHighPrec=32.5%
#   → monotonic folds: 1/3
#   💾 saved combo model: model_combo_108.pkl
#   elapsed 270.9 min | ETA 983.3 min
#
# ================================================================================
# SEARCH COMPLETE in 270.9 min
# ================================================================================
#
# Best hyperparameters (incl. tuned n_estimators):
#   subsample         : 0.8
#   reg_lambda        : 2
#   reg_alpha         : 0
#   n_estimators      : 500
#   min_child_weight  : 2
#   max_depth         : 16
#   learning_rate     : 0.1
#   gamma             : 0
#   colsample_bytree  : 0.8
#   MEDIUM_WEIGHT_MULT: 1
#   HIGH_WEIGHT_MULT  : 0.75
#
# Best CV score: -2.4046

# %% [markdown]
# ## **STEP 10: Train Final Model (SMOTENC)**
#
# Uses the winning hyperparameters — including the cross-validated `n_estimators` — so the deployed model is exactly the one that was validated.

# %%
print("="*80)
print("FINAL MODEL TRAINING")
print("="*80)
fstart=time.time()

if classes_to_oversample:
    '''
    # Comment out if there are NaN as SMOTENC can't handle
    print("Applying SMOTENC to full training data...")
    sm=SMOTENC(categorical_features=categorical_indices,
               sampling_strategy=classes_to_oversample,k_neighbors=5,
               random_state=RANDOM_STATE)
    X_res,y_res=sm.fit_resample(X_train,y_train_numeric)
    '''
    print("Applying RandomOS to full training data...")
    ros=RandomOverSampler(sampling_strategy=classes_to_oversample,
                      random_state=RANDOM_STATE)
    X_res,y_res=ros.fit_resample(X_train,y_train_numeric)
    print(f"  {len(X_train):,} → {len(X_res):,} samples")
    for c in range(n_cls):
        lbl=[k for k,v in label_mapping.items() if v==c][0]
        cnt=(y_res==c).sum()
        print(f"    {lbl:8s}: {cnt:,} ({cnt/len(y_res)*100:.1f}%)")
else:
    print("No oversampling needed — training on original data")
    X_res,y_res=X_train,y_train_numeric

print("\nTraining final model (using cross-validated n_estimators)...")
final_model=xgb.XGBClassifier(**{**fixed_params,**xgb_params(best_params)})
final_model.fit(X_res,y_res,sample_weight=y_res.map(weights_from_combo(best_params)),
                verbose=False)
print(f"  class weights used: {weights_from_combo(best_params)}")
final_time=time.time()-fstart
print(f"✓ Final model trained in {final_time/60:.1f} min "
      f"(n_estimators={best_params['n_estimators']})")
print()
# Out:
# ================================================================================
# FINAL MODEL TRAINING
# ================================================================================
# No oversampling needed — training on original data
#
# Training final model (using cross-validated n_estimators)...
#   class weights used: {0: 1.0, 1: 1.0, 2: 1.0, 3: 0.75}
# ✓ Final model trained in 1.3 min (n_estimators=500)

# %% [markdown]
# ## **STEP 11: Feature Importance**

# %%
print("-"*80)
print("FEATURE IMPORTANCE (top 25)")
print("-"*80)
fi=pd.DataFrame({'feature':feature_columns,'importance':final_model.feature_importances_}
    ).sort_values('importance',ascending=False)
print(fi.head(25).to_string(index=False))
fi.to_csv(os.path.join(OUTPUT_FOLDER,'feature_importance.csv'),index=False)
print("\n✓ feature_importance.csv saved")
print("\nTip: to prune, copy weak feature names into a CSV with column")
print("     'feature_name', set PRUNE_FILE in Step 2, and re-run from Step 3.")
print()
# Out:
# --------------------------------------------------------------------------------
# FEATURE IMPORTANCE (top 25)
# --------------------------------------------------------------------------------
#                           feature  importance
#                  mapped_commodity    0.018588
#             commodity_correlation    0.017790
#                cluster_num_stocks    0.016511
#       commodity_max_drawdown_120d    0.010845
#         commodity_volatility_120d    0.010815
#            Commodity_Alignment_1d    0.010322
#                           cluster    0.010230
#          commodity_volatility_60d    0.009833
#            cluster_max_return_60d    0.009635
#          commodity_volatility_10d    0.009539
#             commodity_return_120d    0.009363
#          commodity_volatility_20d    0.008984
#            Commodity_Alignment_5d    0.008978
#                      Market_Trend    0.008968
#        commodity_max_drawdown_20d    0.008919
#               commodity_return_1d    0.008667
#  commodity_distance_from_high_20d    0.008575
#         commodity_volatility_252d    0.008508
# commodity_positive_days_ratio_20d    0.008343
#          commodity_min_return_60d    0.008325
#             commodity_return_252d    0.008314
#               cluster_correlation    0.008224
#              commodity_sharpe_60d    0.008163
#           Commodity_Alignment_60d    0.008137
#                            SMA_50    0.008069
#
# ✓ feature_importance.csv saved
#
# Tip: to prune, copy weak feature names into a CSV with column
#      'feature_name', set PRUNE_FILE in Step 2, and re-run from Step 3.

# %% [markdown]
# ## **STEP 12: Save Artefacts**

# %%
print("="*80)
print("SAVING ARTEFACTS")
print("="*80)

def save_pickle(obj, name):
    p=os.path.join(OUTPUT_FOLDER,name)
    with open(p,'wb') as f: pickle.dump(obj,f)
    print(f"  ✓ {name}")
    return p

save_pickle(final_model,'best_model.pkl')
save_pickle(label_encoders,'categorical_encoders.pkl')
save_pickle(label_mapping,'label_mapping.pkl')
save_pickle(feature_columns,'feature_columns_model.pkl')
save_pickle(UTILITY_MATRIX,'utility_matrix.pkl')   # Code 8c uses this for the EU decision rule

pd.DataFrame(search_results).to_csv(os.path.join(OUTPUT_FOLDER,'training_results.csv'),index=False)
pd.DataFrame(fold_results).to_csv(os.path.join(OUTPUT_FOLDER,'cv_fold_metrics.csv'),index=False)
print("  ✓ training_results.csv, cv_fold_metrics.csv")

# ── Req2: consolidated GAIN table (feature × fold × combo) + summary ─────────
if COLLECT_GAIN and len(gain_records):
    gain_long = pd.DataFrame(gain_records)
    gain_long.to_csv(os.path.join(OUTPUT_FOLDER, 'gain_by_feature_fold_combo.csv'), index=False)

    # Wide pivot: one row per feature, one column per (combo, fold), value = gain.
    # Every feature appears (zeros are explicit because we recorded all features).
    gain_wide = gain_long.pivot_table(
        index='feature', columns=['iteration', 'fold'], values='gain', fill_value=0.0)
    gain_wide.columns = [f'combo{c}_fold{f}' for c, f in gain_wide.columns]
    gain_wide = gain_wide.reset_index()

    # Summary stats per feature to spot consistently-negligible features
    stat_cols = [c for c in gain_wide.columns if c != 'feature']
    gain_wide['gain_mean']      = gain_wide[stat_cols].mean(axis=1)
    gain_wide['gain_max']       = gain_wide[stat_cols].max(axis=1)
    gain_wide['gain_nonzero_runs'] = (gain_wide[stat_cols] > 0).sum(axis=1)
    gain_wide['total_runs']     = len(stat_cols)
    gain_wide['pct_runs_zero']  = (1 - gain_wide['gain_nonzero_runs'] / len(stat_cols)) * 100
    # Flag: never used in any tree across any fold/combo → always-zero gain
    gain_wide['always_zero']    = gain_wide['gain_nonzero_runs'] == 0
    # Order: worst (always zero, then lowest mean gain) first → easy prune scan
    gain_wide = gain_wide.sort_values(['always_zero', 'gain_mean'],
                                      ascending=[False, True])

    # Put summary columns first for readability
    front = ['feature', 'gain_mean', 'gain_max', 'gain_nonzero_runs',
             'total_runs', 'pct_runs_zero', 'always_zero']
    gain_wide = gain_wide[front + [c for c in gain_wide.columns if c not in front]]
    gain_wide.to_csv(os.path.join(OUTPUT_FOLDER, 'gain_summary_by_feature.csv'), index=False)

    n_always_zero = int(gain_wide['always_zero'].sum())
    print(f"  ✓ gain_by_feature_fold_combo.csv (long: {len(gain_long):,} rows)")
    print(f"  ✓ gain_summary_by_feature.csv (all {len(gain_wide)} features, zeros explicit)")
    print(f"    Features with ZERO gain in EVERY fold×combo: {n_always_zero} "
          f"(prime prune candidates)")

# ── Req1: shared fileset so each combo model is runnable in Code 8c ──────────
if SAVE_COMBO_MODELS and len(combo_model_paths):
    # The encoders / label_mapping / feature_columns are identical for all combos
    # (only hyperparameters differ), so one shared copy lives in combo_models/.
    for obj, nm in [(label_encoders, 'categorical_encoders.pkl'),
                    (label_mapping, 'label_mapping.pkl'),
                    (feature_columns, 'feature_columns_model.pkl'),
                    (UTILITY_MATRIX, 'utility_matrix.pkl')]:
        with open(os.path.join(COMBO_DIR, nm), 'wb') as _f:
            pickle.dump(obj, _f)
    pd.DataFrame(combo_model_paths).to_csv(
        os.path.join(COMBO_DIR, 'combo_model_index.csv'), index=False)
    print(f"  ✓ {len(combo_model_paths)} per-combo models in combo_models/ "
          f"(+ shared encoders/label_map/feature_cols + index)")

with open(os.path.join(OUTPUT_FOLDER,'best_hyperparameters.txt'),'w') as f:
    f.write("BEST HYPERPARAMETERS\n"+"="*60+"\n\n")
    f.write(f"Best CV score : {best_score:.4f}\n")
    f.write(f"Label mapping : {label_mapping}\n\n")
    for p,v in best_params.items(): f.write(f"  {p:18s}: {v}\n")
print("  ✓ best_hyperparameters.txt")

print(f"\nLabel mapping saved: {label_mapping}")
print(f"Features saved     : {len(feature_columns)}")
print()
# Out:
# ================================================================================
# SAVING ARTEFACTS
# ================================================================================
#   ✓ best_model.pkl
#   ✓ categorical_encoders.pkl
#   ✓ label_mapping.pkl
#   ✓ feature_columns_model.pkl
#   ✓ utility_matrix.pkl
#   ✓ training_results.csv, cv_fold_metrics.csv
#   ✓ gain_by_feature_fold_combo.csv (long: 82,944 rows)
#   ✓ gain_summary_by_feature.csv (all 256 features, zeros explicit)
#     Features with ZERO gain in EVERY fold×combo: 0 (prime prune candidates)
#   ✓ 108 per-combo models in combo_models/ (+ shared encoders/label_map/feature_cols + index)
#   ✓ best_hyperparameters.txt
#
# Label mapping saved: {'Ignore': 0, 'Low': 1, 'Medium': 2, 'High': 3}
# Features saved     : 256

# %% [markdown]
# ## **STEP 13: Auto-Download All Outputs**

# %%
print("="*80)
print("AUTO-DOWNLOADING OUTPUTS")
print("="*80)
from google.colab import files
import shutil

# List everything (including the combo_models/ subfolder) for transparency
print("Output files:")
for root, _, fs in os.walk(OUTPUT_FOLDER):
    for fn in sorted(fs):
        fp = os.path.join(root, fn)
        rel = os.path.relpath(fp, OUTPUT_FOLDER)
        print(f"  {rel:45s} ({os.path.getsize(fp)/1024:8.1f} KB)")

# Zip the WHOLE output folder (recurses into combo_models/) → one download.
# This avoids browser multi-download throttling AND includes the per-combo models.
zip_path = shutil.make_archive('/content/model_outputs_8b', 'zip', OUTPUT_FOLDER)
print(f"\n✓ Zipped all outputs ({os.path.getsize(zip_path)/(1024*1024):.1f} MB)")
files.download(zip_path)
print("✓ Downloading model_outputs_8b.zip")

print("\n"+"="*80)
print("CODE 8b COMPLETE")
print("="*80)
print("\nThe zip contains:")
print("  • best_model.pkl + categorical_encoders.pkl + label_mapping.pkl +")
print("    feature_columns_model.pkl  (the SELECTED model fileset for Code 8c)")
print("  • combo_models/  (Req1: every combo's full-data model + shared fileset")
print("    + combo_model_index.csv — each is runnable in 8c)")
print("  • gain_by_feature_fold_combo.csv + gain_summary_by_feature.csv  (Req2)")
print("  • training_results.csv, cv_fold_metrics.csv, feature_importance.csv")
print()
# Out:
# ================================================================================
# AUTO-DOWNLOADING OUTPUTS
# ================================================================================
# Output files:
#   best_hyperparameters.txt                      (     0.4 KB)
#   best_model.pkl                                (114426.2 KB)
#   categorical_encoders.pkl                      (     2.4 KB)
#   cleaning_report.csv                           (    15.3 KB)
#   cv_fold_metrics.csv                           (    63.9 KB)
#   data_quality_after.csv                        (    10.6 KB)
#   data_quality_before.csv                       (    11.7 KB)
#   feature_columns_model.pkl                     (     5.1 KB)
#   feature_importance.csv                        (     7.8 KB)
#   gain_by_feature_fold_combo.csv                (  3404.2 KB)
#   gain_summary_by_feature.csv                   (  1520.7 KB)
#   label_mapping.pkl                             (     0.1 KB)
#   training_results.csv                          (    13.7 KB)
#   utility_matrix.pkl                            (     0.3 KB)
#   combo_models/categorical_encoders.pkl         (     2.4 KB)
#   combo_models/combo_model_index.csv            (    11.9 KB)
#   combo_models/feature_columns_model.pkl        (     5.1 KB)
#   combo_models/label_mapping.pkl                (     0.1 KB)
#   combo_models/model_combo_001.pkl              (  3315.2 KB)
#   combo_models/model_combo_002.pkl              (  4636.9 KB)
#   combo_models/model_combo_003.pkl              (  5955.3 KB)
#   combo_models/model_combo_004.pkl              (  5204.1 KB)
#   combo_models/model_combo_005.pkl              (  7291.2 KB)
#   combo_models/model_combo_006.pkl              (  9376.0 KB)
#   combo_models/model_combo_007.pkl              (  8573.7 KB)
#   combo_models/model_combo_008.pkl              ( 12026.4 KB)
#   combo_models/model_combo_009.pkl              ( 15473.5 KB)
#   combo_models/model_combo_010.pkl              ( 14326.0 KB)
#   combo_models/model_combo_011.pkl              ( 20097.8 KB)
#   combo_models/model_combo_012.pkl              ( 25783.8 KB)
#   combo_models/model_combo_013.pkl              ( 23382.7 KB)
#   combo_models/model_combo_014.pkl              ( 32563.5 KB)
#   combo_models/model_combo_015.pkl              ( 41275.5 KB)
#   combo_models/model_combo_016.pkl              ( 52262.2 KB)
#   combo_models/model_combo_017.pkl              ( 67205.3 KB)
#   combo_models/model_combo_018.pkl              ( 78944.3 KB)
#   combo_models/model_combo_019.pkl              ( 81393.3 KB)
#   combo_models/model_combo_020.pkl              ( 96110.3 KB)
#   combo_models/model_combo_021.pkl              (106913.8 KB)
#   combo_models/model_combo_022.pkl              (101442.5 KB)
#   combo_models/model_combo_023.pkl              (114836.4 KB)
#   combo_models/model_combo_024.pkl              (124667.4 KB)
#   combo_models/model_combo_025.pkl              (114426.2 KB)
#   combo_models/model_combo_026.pkl              (126773.0 KB)
#   combo_models/model_combo_027.pkl              (135960.6 KB)
#   combo_models/model_combo_028.pkl              (  3317.2 KB)
#   combo_models/model_combo_029.pkl              (  4637.6 KB)
#   combo_models/model_combo_030.pkl              (  5956.5 KB)
#   combo_models/model_combo_031.pkl              (  5206.6 KB)
#   combo_models/model_combo_032.pkl              (  7297.2 KB)
#   combo_models/model_combo_033.pkl              (  9380.2 KB)
#   combo_models/model_combo_034.pkl              (  8579.0 KB)
#   combo_models/model_combo_035.pkl              ( 12050.9 KB)
#   combo_models/model_combo_036.pkl              ( 15521.6 KB)
#   combo_models/model_combo_037.pkl              ( 14377.5 KB)
#   combo_models/model_combo_038.pkl              ( 20132.2 KB)
#   combo_models/model_combo_039.pkl              ( 25836.9 KB)
#   combo_models/model_combo_040.pkl              ( 23481.4 KB)
#   combo_models/model_combo_041.pkl              ( 32546.7 KB)
#   combo_models/model_combo_042.pkl              ( 41305.6 KB)
#   combo_models/model_combo_043.pkl              ( 52772.2 KB)
#   combo_models/model_combo_044.pkl              ( 68102.9 KB)
#   combo_models/model_combo_045.pkl              ( 80008.0 KB)
#   combo_models/model_combo_046.pkl              ( 82622.8 KB)
#   combo_models/model_combo_047.pkl              ( 97460.6 KB)
#   combo_models/model_combo_048.pkl              (108387.9 KB)
#   combo_models/model_combo_049.pkl              (103259.2 KB)
#   combo_models/model_combo_050.pkl              (116703.8 KB)
#   combo_models/model_combo_051.pkl              (126654.9 KB)
#   combo_models/model_combo_052.pkl              (116927.8 KB)
#   combo_models/model_combo_053.pkl              (129278.5 KB)
#   combo_models/model_combo_054.pkl              (138496.0 KB)
#   combo_models/model_combo_055.pkl              (  3316.6 KB)
#   combo_models/model_combo_056.pkl              (  4634.9 KB)
#   combo_models/model_combo_057.pkl              (  5953.3 KB)
#   combo_models/model_combo_058.pkl              (  5205.8 KB)
#   combo_models/model_combo_059.pkl              (  7294.6 KB)
#   combo_models/model_combo_060.pkl              (  9386.5 KB)
#   combo_models/model_combo_061.pkl              (  8623.0 KB)
#   combo_models/model_combo_062.pkl              ( 12109.2 KB)
#   combo_models/model_combo_063.pkl              ( 15586.3 KB)
#   combo_models/model_combo_064.pkl              ( 14359.0 KB)
#   combo_models/model_combo_065.pkl              ( 20172.2 KB)
#   combo_models/model_combo_066.pkl              ( 25919.5 KB)
#   combo_models/model_combo_067.pkl              ( 23809.2 KB)
#   combo_models/model_combo_068.pkl              ( 33144.5 KB)
#   combo_models/model_combo_069.pkl              ( 41971.5 KB)
#   combo_models/model_combo_070.pkl              ( 53611.8 KB)
#   combo_models/model_combo_071.pkl              ( 69250.3 KB)
#   combo_models/model_combo_072.pkl              ( 81318.3 KB)
#   combo_models/model_combo_073.pkl              ( 84631.2 KB)
#   combo_models/model_combo_074.pkl              ( 99488.9 KB)
#   combo_models/model_combo_075.pkl              (110425.2 KB)
#   combo_models/model_combo_076.pkl              (105598.1 KB)
#   combo_models/model_combo_077.pkl              (119206.0 KB)
#   combo_models/model_combo_078.pkl              (129108.1 KB)
#   combo_models/model_combo_079.pkl              (119780.9 KB)
#   combo_models/model_combo_080.pkl              (132101.3 KB)
#   combo_models/model_combo_081.pkl              (141333.6 KB)
#   combo_models/model_combo_082.pkl              (  3315.2 KB)
#   combo_models/model_combo_083.pkl              (  4634.0 KB)
#   combo_models/model_combo_084.pkl              (  5952.9 KB)
#   combo_models/model_combo_085.pkl              (  5207.7 KB)
#   combo_models/model_combo_086.pkl              (  7299.5 KB)
#   combo_models/model_combo_087.pkl              (  9390.8 KB)
#   combo_models/model_combo_088.pkl              (  8612.1 KB)
#   combo_models/model_combo_089.pkl              ( 12066.7 KB)
#   combo_models/model_combo_090.pkl              ( 15557.0 KB)
#   combo_models/model_combo_091.pkl              ( 14433.9 KB)
#   combo_models/model_combo_092.pkl              ( 20225.3 KB)
#   combo_models/model_combo_093.pkl              ( 25969.4 KB)
#   combo_models/model_combo_094.pkl              ( 23709.0 KB)
#   combo_models/model_combo_095.pkl              ( 33095.1 KB)
#   combo_models/model_combo_096.pkl              ( 41983.9 KB)
#   combo_models/model_combo_097.pkl              ( 54009.0 KB)
#   combo_models/model_combo_098.pkl              ( 69906.2 KB)
#   combo_models/model_combo_099.pkl              ( 82195.1 KB)
#   combo_models/model_combo_100.pkl              ( 85826.9 KB)
#   combo_models/model_combo_101.pkl              (100971.7 KB)
#   combo_models/model_combo_102.pkl              (111918.4 KB)
#   combo_models/model_combo_103.pkl              (107432.5 KB)
#   combo_models/model_combo_104.pkl              (120957.4 KB)
#   combo_models/model_combo_105.pkl              (130886.3 KB)
#   combo_models/model_combo_106.pkl              (121281.3 KB)
#   combo_models/model_combo_107.pkl              (133753.4 KB)
#   combo_models/model_combo_108.pkl              (142974.2 KB)
#   combo_models/utility_matrix.pkl               (     0.3 KB)
#
# ✓ Zipped all outputs (2839.6 MB)
# ✓ Downloading model_outputs_8b.zip
#
# ================================================================================
# CODE 8b COMPLETE
# ================================================================================
#
# The zip contains:
#   • best_model.pkl + categorical_encoders.pkl + label_mapping.pkl +
#     feature_columns_model.pkl  (the SELECTED model fileset for Code 8c)
#   • combo_models/  (Req1: every combo's full-data model + shared fileset
#     + combo_model_index.csv — each is runnable in 8c)
#   • gain_by_feature_fold_combo.csv + gain_summary_by_feature.csv  (Req2)
#   • training_results.csv, cv_fold_metrics.csv, feature_importance.csv
